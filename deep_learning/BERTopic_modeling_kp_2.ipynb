# %% [markdown]
# things to do tomorrow:
#
# check topic difference with and without stopwords (and changing when to remove stopwords?) and interpret topics qualitatively! maybe with Richard?

# %% [markdown]
# ## Setup

# %%
# !pip install bertopic[visualization] --quiet
# Out:
#      |████████████████████████████████| 90 kB 2.5 MB/s
# WARNING: bertopic 0.12.0 does not provide the extra 'visualization'
#      |████████████████████████████████| 662 kB 34.8 MB/s
#      |████████████████████████████████| 88 kB 5.2 MB/s
#      |████████████████████████████████| 85 kB 2.9 MB/s
#      |████████████████████████████████| 5.2 MB 13.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 5.8 MB 28.1 MB/s
#      |████████████████████████████████| 1.3 MB 69.5 MB/s
#      |████████████████████████████████| 182 kB 60.0 MB/s
#      |████████████████████████████████| 7.6 MB 50.5 MB/s
#      |████████████████████████████████| 1.1 MB 55.3 MB/s
# ...

# %%
import numpy as np
import pandas as pd
from copy import deepcopy
from bertopic import BERTopic

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#paths on odelia's drive
#fp = pd.read_csv('gdrive/My Drive/Colab Notebooks/far_right/false_positives.csv', index_col = [0])
#fn = pd.read_csv('gdrive/My Drive/Colab Notebooks/far_right/false_negatives.csv', index_col = [0])

#paths on konrat's drive
fp = pd.read_csv('/content/gdrive/MyDrive/data/false_positives.csv', index_col = [0])
fn = pd.read_csv('/content/gdrive/MyDrive/data/false_negatives.csv', index_col = [0])
full = pd.read_csv('/content/gdrive/MyDrive/data/clean_fullsample_test.csv', index_col = [0])

# %% [markdown]
# ## Topic Modeling on Rows Classified as 1 instead of 0 [False Positives]

# %% [markdown]
# ### Without Set Amount of Topics

# %%
fp
# Out:
#                                       contribution_text  \
# 0     Mr President in my own country Sweden a priest...
# 1     \n    Mr President the people of Venezuela too...
# 2       The main reason for my voting against adopti...
# 3     Madam President ladies and gentlemen it seems ...
# 4     Madam President I want to speak on the motion ...
# ...                                                 ...
# 1780  Mr President I want to congratulate Mr McMahon...
# 1781  Mr President ladies and gentlemen the call for...
# 1782    Rum is no longer sufficient fodder in the FO...
# 1783  Mr President the first sentence of paragraph 1...
# 1784  \n   Mr President this debate has been a clash...
#
#                                           chapter_title speaker_name_lower  \
# 0                                                  Iraq          malmström
# 1                                                     <            patakis
# ...

# %%
docs_fp = list(fp.loc[:, "contribution_text"].values)

# %%
model_fp = BERTopic(language="english")

# %%
topics, probs = model_fp.fit_transform(docs_fp)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
model_fp.get_topic_freq()
# Out:
#     Topic  Count
# 0      -1    568
# 1       0    149
# 2       1     85
# 3       2     80
# 4       3     68
# 5       4     63
# 6       5     49
# 7       6     48
# 8       7     48
# 9       8     41
# 10      9     37
# 11     10     37
# 12     11     34
# 13     12     33
# 14     13     32
# 15     14     31
# 16     15     31
# 17     16     30
# 18     17     27
# 19     18     26
# 20     19     25
# 21     20     24
# 22     21     23
# 23     22     23
# 24     23     19
# 25     24     19
# 26     25     19
# 27     26     17
# 28     27     16
# 29     28     15
# 30     29     14
# 31     30     12
# 32     31     11
# 33     32     11
# 34     33     10
# 35     34     10

# %%
model_fp.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#clusters:

cluster_1 = [0, 2, 3, 4, 6, 7, 12, 19, 21, 26, 34]
cluster_2 = [15, 18, 30]
cluster_3 = [1, 8, 11]
cluster_4 = [9, 25, 32]
cluster_5 = [5, 10, 14, 20, 22, 28]
cluster_6 = [13, 16, 17, 23, 24, 27, 29, 31, 33]

# %%
cluster_1_words = []
cluster_2_words = []
cluster_3_words = []
cluster_4_words = []
cluster_5_words = []
cluster_6_words = []

for i in range(35):
  if i in cluster_1:
    cluster_1_words.append([j[0] for j in model.get_topic(i)])
  if i in cluster_2:
    cluster_2_words.append([j[0] for j in model.get_topic(i)])
  if i in cluster_3:
    cluster_3_words.append([j[0] for j in model.get_topic(i)])
  if i in cluster_4:
    cluster_4_words.append([j[0] for j in model.get_topic(i)])
  if i in cluster_5:
    cluster_5_words.append([j[0] for j in model.get_topic(i)])
  if i in cluster_6:
    cluster_6_words.append([j[0] for j in model.get_topic(i)])

# %%
pre_df_dict = {}

pre_df_dict['cluster 1'] = [cluster_1_words]
pre_df_dict['cluster 2'] = [cluster_2_words]
pre_df_dict['cluster 3'] = [cluster_3_words]
pre_df_dict['cluster 4'] = [cluster_4_words]
pre_df_dict['cluster 5'] = [cluster_5_words]
pre_df_dict['cluster 6'] = [cluster_6_words]

# %%
clusters_df = pd.DataFrame.from_dict(pre_df_dict).T

# %%
clusters_df
# Out:
#                                                            0
# cluster 1  [[you, vote, president, amendment, mr, was, pr...
# cluster 2  [[china, chinese, tibet, tibetan, taiwan, righ...
# cluster 3  [[fishing, fisheries, fishermen, fish, stocks,...
# cluster 4  [[agricultural, rural, farmers, agriculture, c...
# cluster 5  [[sudan, africa, zimbabwe, african, we, and, u...
# cluster 6  [[disaster, disasters, solidarity, fund, affec...

# %%
#clusters_df.to_csv('clusters_df.csv')

# %% [markdown]
# ### With Set Amount of Topics

# %%
docs_fp_set = list(fp.loc[:, "contribution_text"].values)

# %%
model_fp_set = BERTopic(language="english", nr_topics = 6, top_n_words = 30)

# %%
topics_fp_set, probs_fp_set = model_fp_set.fit_transform(docs_fp_set)

# %%
model_fp_set.get_topic_freq()
# Out:
#    Topic  Count
# 0     -1   1346
# 1      0    122
# 2      1     82
# 3      2     81
# 4      3     56
# 5      4     49
# 6      5     49

# %%
model_fp_set.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model_fp_set.get_topic(3)
# Out:
# [('the', 0.07855119291058664),
#  ('russia', 0.06884404100018499),
#  ('of', 0.0546471669531919),
#  ('to', 0.05461141029833967),
#  ('and', 0.054183548150980254),
#  ('in', 0.04528513603307614),
#  ('russian', 0.040587388301907765),
#  ('is', 0.04010787059069627),
#  ('that', 0.03803848325455351),
#  ('we', 0.030145508140103475),
#  ('it', 0.029074032964036028),
#  ('not', 0.02610298422616539),
#  ('for', 0.02568538644253006),
#  ('with', 0.02542644332376626),
#  ('this', 0.02318396223499472),
#  ('be', 0.02294490712482642),
#  ('as', 0.022415988280145727),
#  ('on', 0.022168204447554116),
#  ('has', 0.02001320097998156),
#  ('have', 0.019372995371364967),
#  ('european', 0.019090473664841748),
#  ('its', 0.019014377439696493),
#  ('union', 0.0189901476259144),
#  ('are', 0.01891007497635485),
#  ('which', 0.018776856241764017),
#  ('but', 0.018376830058914582),
#  ('will', 0.01773704367095399),
#  ('by', 0.017382975335872047),
#  ('ukraine', 0.016712875586877143),
# ...

# %%
model_fp_set.get_representative_docs(0)
# Out:
# ['Mr President when Member States ratify the Reform Treaty as we hope and believe they will we can look forward at long last to a revitalised European Union  a Union with the capacity to confront new challenges with the humility to listen to its citizens and with the political will to act Ratification of the Treaty cannot come a moment too soon and my Group thanks you Mr Zapatero for your efforts to speed up the process My Group sees no need for a group of wise people to ponder Europes future We have been there done that and even have the Tshirts to prove it It was called the period of reflection and it has come to an end We are midway through the Lisbon Strategy and are only now making progress in growth and jobs We are completing the single market freeing up the potential of Europes entrepreneurs We are opening legal migration pathways to help both developing and developed economies Now is not the time to go back to a French drawing board nor to follow a new British plan for a glor
# ...

# %%
model_fp_set.get_params()
# Out:
# {'calculate_probabilities': False,
#  'ctfidf_model': ClassTfidfTransformer(),
#  'diversity': None,
#  'embedding_model': <bertopic.backend._sentencetransformers.SentenceTransformerBackend at 0x7f2b39beb460>,
#  'hdbscan_model': HDBSCAN(min_cluster_size=10, prediction_data=True),
#  'language': 'english',
#  'low_memory': False,
#  'min_topic_size': 10,
#  'n_gram_range': (1, 1),
#  'nr_topics': 6,
#  'seed_topic_list': None,
#  'top_n_words': 30,
#  'umap_model': UMAP(angular_rp_forest=True, low_memory=False, metric='cosine', min_dist=0.0, n_components=5, tqdm_kwds={'bar_format': '{desc}: {percentage:3.0f}%| {bar} {n_fmt}/{total_fmt} [{elapsed}]', 'desc': 'Epochs completed', 'disable': True}),
#  'vectorizer_model': CountVectorizer(),
#  'verbose': False}

# %% [markdown]
# ## Topic Modeling on Rows Classified as 0 instead of 1 [False Negatives]

# %%
fn
# Out:
#                                       contribution_text  \
# 0     Mr President ladies and gentlemen let us not g...
# 1     in writing   Social security systems differ de...
# 2       At a time when the peoples of Europe are fac...
# 3      The adopted draft resolution of the European ...
# 4        In general the Elles report is a very good ...
# ...                                                 ...
# 5951  in writing   The fifth report on economic soci...
# 5952  Mr President Commissioner ladies and gentlemen...
# 5953  Mr President Commissioner ladies and gentlemen...
# 5954  in writing  The European airline industry and ...
# 5955  \n    Mr President this morning Parliaments ag...
#
#                                           chapter_title  \
# 0                                          Human rights
# 1     13. Active inclusion of people excluded from t...
# 2     Guidelines for the employment policies of the ...
# 3                                  Explanations of vote
# ...

# %%
docs_fn = list(fn.loc[:, "contribution_text"].values)

# %%
model_fn = BERTopic(language="english")

# %%
topics_fn, probs_fn = model_fn.fit_transform(docs_fn)

# %%
model_fn.get_topic_freq()
# Out:
#      Topic  Count
# 0       -1   1882
# 1        0    272
# 2        1    138
# 3        2    114
# 4        3    106
# ..     ...    ...
# 116    115     11
# 117    116     11
# 118    117     11
# 119    118     10
# 120    119     10
#
# [121 rows x 2 columns]

# %%
model_fn.get_topic(5)
# Out:
# [('budget', 0.03164263193762976),
#  ('eur', 0.011278909384131274),
#  ('expenditure', 0.010730923486798506),
#  ('budgetary', 0.008884374518236149),
#  ('the', 0.008579503667023057),
#  ('for', 0.008478269208753218),
#  ('financial', 0.008133630453025967),
#  ('is', 0.008020098834347934),
#  ('billion', 0.007838272317369128),
#  ('european', 0.007707345527610438)]

# %%
model_fn.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Topic Modeling on Actual Far-Right Speeches

# %%
#create dataset of true positives
tp = full[full['far_right'] == 1]

# %%
tp
# Out:
#                                         contribution_text  \
# 109360  Mr President ladies and gentlemen let us not g...
# 37279   in writing   Social security systems differ de...
# 106893  Mr President I should like to warn against our...
# 76460     At a time when the peoples of Europe are fac...
# 50414    The adopted draft resolution of the European ...
# ...                                                   ...
# 54074   in writing   The fifth report on economic soci...
# 122284  Mr President Commissioner ladies and gentlemen...
# 58078   Mr President Commissioner ladies and gentlemen...
# 47756   in writing  The European airline industry and ...
# 3077    \n    Mr President this morning Parliaments ag...
#
#                                             chapter_title  \
# 109360                                       Human rights
# 37279   13. Active inclusion of people excluded from t...
# 106893                         Statement by the President
# ...

# %%
docs_tp = list(tp.loc[:, "contribution_text"].values)

# %%
model_tp = BERTopic(language="english")

# %%
topics_tp, probs_tp = model_tp.fit_transform(docs_tp)

# %%
model_tp.get_topic_freq()
# Out:
#      Topic  Count
# 0       -1   2169
# 1        0    304
# 2        1    185
# 3        2    163
# 4        3    161
# ..     ...    ...
# 128    127     11
# 129    128     11
# 130    129     10
# 131    130     10
# 132    131     10
#
# [133 rows x 2 columns]

# %%
model_tp.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Miscellaneous

# %%
docs_test = list(fp.loc[:, "contribution_text"].values)

# %%
model_fp_test = BERTopic(language="english", nr_topics = 'auto', top_n_words = 30)

# %%
topics_test, probs_test = model_fp_test.fit_transform(docs_test)

# %%
model_fp_test.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#clusters:

cluster_1 = [0, 2, 5, 6, 16, 18, 21, 22, 24, 32]
cluster_2 = [1, 10, 11, 12, 13, 14, 17, 25, 28]
cluster_3 = [3, 4, 7, 9, 15, 26, 29, 31]
cluster_4 = [8, 19, 20, 23, 27, 30]

# %%
cluster_1_words = []
cluster_2_words = []
cluster_3_words = []
cluster_4_words = []

for i in range(35):
  if i in cluster_1:
    cluster_1_words.append([j[0] for j in model.get_topic(i)])
  if i in cluster_2:
    cluster_2_words.append([j[0] for j in model.get_topic(i)])
  if i in cluster_3:
    cluster_3_words.append([j[0] for j in model.get_topic(i)])
  if i in cluster_4:
    cluster_4_words.append([j[0] for j in model.get_topic(i)])

# %%
pre_df_dict = {}

pre_df_dict['cluster 1'] = [cluster_1_words]
pre_df_dict['cluster 2'] = [cluster_2_words]
pre_df_dict['cluster 3'] = [cluster_3_words]
pre_df_dict['cluster 4'] = [cluster_4_words]

# %%
final_clusters = pd.DataFrame.from_dict(pre_df_dict).T

# %%
final_clusters = final_clusters.explode(0)

# %%
final_clusters
#final_clusters.to_csv('final_clusters.csv')
# Out:
#                                                            0
# cluster 1  [you, vote, president, amendment, mr, was, pro...
# cluster 1  [budget, expenditure, the, eur, for, increase,...
# cluster 1  [sudan, africa, zimbabwe, african, we, and, un...
# cluster 1  [kosovo, croatia, serbia, albania, that, milos...
# cluster 1  [nuclear, power, safety, energy, chernobyl, re...
# cluster 1  [discharge, commission, auditors, budget, comm...
# cluster 1  [parties, european, political, you, is, eu, pe...
# cluster 1  [education, young, programme, students, traini...
# cluster 1  [air, passengers, aviation, airlines, traffic,...
# cluster 1  [rail, transport, tunnel, railway, road, railw...
# cluster 2  [fishing, fisheries, fishermen, fish, stocks, ...
# cluster 2  [energy, gas, electricity, renewable, supply, ...
# cluster 2  [employment, social, unemployment, jobs, worki...
# cluster 2  [defence, security, policy, military, cfsp, fo...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
