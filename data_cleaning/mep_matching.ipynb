# %% [markdown]
# # Creating a data frame with Members of European Parliament (MEPS) names and their political parties affiliations

# %% [markdown]
# The purpose of this notebook is to unite files from [Dataset on Members of the European Parliament (1979-2019)](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/V2FJEF) in one data frame that contains information about Members of European Parliament (MEPS) for the period of 1996-2011.
#
# This data frame is used to match Members of European Parliament with their political parties affiliations as one of the data preprocessing steps in [data_cleaning_preprocessing.ipynb](data_cleaning_preprocessing.ipynb).
#
# If you want to run this notebook, you need to download the necessary files following [this link](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/V2FJEF).
# Please, download the following files:
# * Dataset MEPs EP4 1994-1999.xlsx
# * Dataset MEPs EP5 1999-2004.xlsx
# * Dataset MEPs EP 6 2004-2009.xlsx
# * Dataset MEPs 7EP 2009-2014.xlsx
#
# Create a folder 'mep_data/' in the same folder as this notebook, and place the downloaded files there. The notebook will be
# ready to run.
#
# This code produces a 'MEP_dataframe.csv' ready to be used in [data_cleaning_preprocessing.ipynb](data_cleaning_preprocessing.ipynb).

# %% [markdown]
# ## Upload files
# To run this notebook you need to download the files mentioned above, create a folder 'mep_data/' in the same folder as this notebook, and place the downloaded files there.

# %%
import pandas as pd
import os
# ! pip install openpyxl

# %%
# ignore warnings to increase readability of this notebook, feel free to outcomment them
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)

# %%
import os
path = os.getcwd()
file_names = [os.path.join(path,'mep_data/Dataset MEPs EP4 1994-1999.xlsx'),
            os.path.join(path,'mep_data/Dataset MEPs EP5 1999-2004.xlsx'),
            os.path.join(path, 'mep_data/Dataset MEPs EP 6 2004-2009.xlsx'),
            os.path.join(path, 'mep_data/Dataset MEPs 7EP 2009-2014.xlsx')
         ]
file_names

# %% [markdown]
# ## Data frames 1994 - 1999, 1999 -2004
# The goal of this code is to unite 4 data frames that have slightly different format and labeling. First we preprocess these data frames separately.
#
# The code under this section is working with the following files:
# * mep_data/Dataset MEPs EP4 1994-1999.xlsx
# * mep_data/Dataset MEPs EP5 1999-2004.xlsx

# %% [markdown]
# ### Extract encodings of the data frames
# The two .xlsx file contains several excel sheets, one of these sheets contains encodings of political parties, e.g. A corresponds to Independents for a European of Nations and Europe of Democracies and Diversities.
#
# Here we upload encodings only from 'Dataset MEPs EP4 1994-1999.xlsx', because they are applicable to both files processed in this section.

# %%
# info from the first file: MEPS_data/5/Dataset MEPs EP4 1994-1999.xlsx
political_parties_df = pd.read_excel(file_names[0], sheet_name = 2)
political_parties_df
# Out:
#                                              EP Group Abbeviation Code
# 0              Independents for a European of Nations       I-EDN    A
# 1               Europe of Democracies and Diversities         EDD    A
# 2                                  European Democrats          ED    C
# 3                             European People's Party         PPE    E
# 4          European People's Party-European Democrats      PPE-DE    E
# 5                                        Forza Europa          FE    F
# 6                      Progressive European Democrats         DEP    G
# 7                        European Democratic Alliance         RDE    G
# 8                                    Union for Europe         UPE    G
# 9                       Union for a Europe of Nations         UEN    G
# 10                       Liberal and Democratic Group           L    L
# 11                Liberal Democratic and Reform Group         LDR    L
# 12       European Liberal Democratic and Reform Party        ELDR    L
# 13                                    Communist Group         COM    M
# 14                                     Left Coalition          CG    O
# 15             European United Left/Nordic Green Left     GUE/NGL    M
# 16                               European United Left         GUE    M
# 17  Technical Coordination of Democrats and Indepe...        CTDI    N
# 18                                       Non-attached          NI    N
# 19                    Technical Group of Independents         TGI    N
# 20  Technical Coordination of Democrats and Indepe...         CDI    R
# 21                                      Rainbow Group         ARC    R
# 22                          European Radical Alliance         ARE    R
# 23                                    Socialist Group           S    S
# 24                       Party of European Socialists         PSE    S
# 25                                        Green Group           V    V
# 26                      Greens/European Free Alliance   Verts/ALE    V
# 27                                     European Right          DR    X

# %% [markdown]
# We group political parties by their codes (A to X) and create a dictionary of these codes and corresponding to them political party names.

# %%
political_party_grouped = political_parties_df.groupby(political_parties_df['Code'], as_index = False).agg(lambda x: list(x))
political_party_dic = dict(zip(political_party_grouped['Code'], political_party_grouped['EP Group']))
# political_party_dic

# %% [markdown]
# One of the excel sheets contains information about national parties, we also extract this information and create a dictionary of national parties encodings.

# %%
national_parties_df = pd.read_excel(file_names[0], sheet_name = 1)
# national_parties_df

# %%
national_party_name_dic = dict(zip(national_parties_df['Code'], national_parties_df['National Party']))
# national_party_name_dic

# %%
national_party_family_dic = dict(zip(national_parties_df['Code'], national_parties_df['Party Family']))
#national_party_family_dic

# %% [markdown]
# ### Assign a far-right or not far-right label to political parties
# Now we assign a label to each political parties code (A to X) telling if it's far right or not far right parties (0,1):
# * 1 - far-right
# * 0 - not far-right
#
# We assign these labels manually based on public information about these political parties.
#
# If you want to see which labels were assigned to which parties compare far_right_dic and political_party_dic.

# %%
far_right_dic = dict(zip(political_parties_df['Code'].unique(), [1, 0, 0, 0, 1, 0, 0, 0, 1, 0, 0, 0, 1]))
far_right_dic
# Out:
# {'A': 1,
#  'C': 0,
#  'E': 0,
#  'F': 0,
#  'G': 1,
#  'L': 0,
#  'M': 0,
#  'O': 0,
#  'N': 1,
#  'R': 0,
#  'S': 0,
#  'V': 0,
#  'X': 1}

# %% [markdown]
# ### Transform data frames to new format
# We create new data frames that contain names of the European Parliament members, far-right vs not far-right labels, and other information that might be useful for the analysis.

# %%
def process_table_1(df, file_name):
    new_table = df.loc[:,['full_name', 'country_name', 'epg_name', 'national party_id']]
    new_table.loc[:,['surname']] = [x.split(" ")[0].lower() for x in new_table['full_name']] 
    new_table.loc[:,['far_right']] = [far_right_dic[x] for x in new_table['epg_name']]
    new_table.loc[:,['epg_names']] = [political_party_dic[x] for x in new_table['epg_name']]
    new_table.loc[:,['national_party_name']] = [national_party_name_dic[x] for x in new_table['national party_id']]
    new_table.loc[:,['national_party_family']] = [national_party_family_dic[x] for x in new_table['national party_id']]
    new_table.loc[:,['years']] = file_name[-14:-5]
    new_table.rename(columns = {'epg_name':'epg_code',
                               'national party_id':'national_party_id',
                               }, inplace = True)
    new_table = new_table[['full_name', 'surname', 'far_right', 'years', 'country_name', 'epg_code', 'epg_names', 'national_party_id', 'national_party_name', 'national_party_family']]
    
    return new_table

# %% [markdown]
# First, the 'Dataset MEPs EP4 1994-1999.xlsx' file

# %%
# read the file
df_1994 = pd.read_excel(file_names[0], sheet_name = 0)

# manually correct data entry mistakes
## Dagmar Reichenbach
df_1994.loc[568, 'epg_name'] = 'S'  # '\xa0\xa0\xa0\xa0\xa0S&D' -> S
df_1994.loc[568, 'national party_id'] = 2407 #'\xa0\xa0\xa0\xa0\xa0Social Democratic Party' -> 2407
## Wagenknecht Sahra
df_1994.loc[719, 'epg_name'] = 'O'  # 'EUL/NGL' -> O
df_1994.loc[719, 'national party_id'] = 1205 # 31 -> 1205

# transform to new format
df_1994 = process_table_1(df_1994, file_names[0])
df_1994
# Out:
# /tmp/ipykernel_5732/3003087342.py:4: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   new_table.loc[:,['far_right']] = [far_right_dic[x] for x in new_table['epg_name']]
#                    full_name       surname  far_right      years country_name  \
# 0             ADAM Gordon J.          adam          0  1994-1999         U.K.
# 1         AELVOET Magda G.H.       aelvoet          0  1994-1999      Belgium
# 2    AGLIETTA Maria Adelaide      aglietta          0  1994-1999        Italy
# 3                AHERN Nuala         ahern          0  1994-1999      Ireland
# 4          AHLQVIST Birgitta      ahlqvist          0  1994-1999       Sweden
# ..                       ...           ...        ...        ...          ...
# 737       WURTH-POLFER Lydie  wurth-polfer          0  1994-1999   Luxembourg
# 738            WURTZ Francis         wurtz          0  1994-1999       France
# 739             WYNN Terence          wynn          0  1994-1999         U.K.
# 740        ZIMMERMANN Wilmya    zimmermann          0  1994-1999      Germany
# 741         ZAPPALA' Stefano      zappala'          0  1994-1999        Italy
#
#     epg_code                                          epg_names  \
# 0          S    [Socialist Group, Party of European Socialists]
# 1          V       [Green Group, Greens/European Free Alliance]
# 2          V       [Green Group, Greens/European Free Alliance]
# 3          V       [Green Group, Greens/European Free Alliance]
# 4          S    [Socialist Group, Party of European Socialists]
# ..       ...                                                ...
# 737        L  [Liberal and Democratic Group, Liberal Democra...
# 738        M  [Communist Group, European United Left/Nordic ...
# 739        S    [Socialist Group, Party of European Socialists]
# 740        S    [Socialist Group, Party of European Socialists]
# 741        E  [European People's Party, European People's Pa...
#
#     national_party_id                                national_party_name  \
# 0                2404                                       Labour Party
# 1                1101              Anders gaan arbeiden, leven en vrijen
# 2                1609  Verdi Arcobaleno / Federazione dei Verdi / Ver...
# 3                2203                                        Green Party
# 4                2306                 Socialdemokratiska arbetarepartiet
# ..                ...                                                ...
# 737              1802                                  Parti démcratique
# 738              1409  Parti communiste française / Gauche unitaire /...
# 739              2404                                       Labour Party
# 740              1207            Sozialdemokratische Partei Deutschlands
# 741              1608                                       Forza Italia
#
#     national_party_family
# 0                     Soc
# 1                     Grn
# 2                     Grn
# 3                     Grn
# 4                     Soc
# ..                    ...
# 737                   Lib
# 738                  Left
# 739                   Soc
# 740                   Soc
# 741                   Con
#
# [742 rows x 10 columns]

# %% [markdown]
# Then, the 'Dataset MEPs EP5 1999-2004.xlsx' file

# %%
# read the file 
df_1999 = pd.read_excel(file_names[1], sheet_name = 0)

# transform the data frame
df_1999 = process_table_1(df_1999, file_names[1])
df_1999
# Out:
# /tmp/ipykernel_5732/3003087342.py:4: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   new_table.loc[:,['far_right']] = [far_right_dic[x] for x in new_table['epg_name']]
#                      full_name   surname  far_right      years country_name  \
# 0                 BERGER Maria    berger          0  1999-2004      Austria
# 1                BÖSCH Herbert     bösch          0  1999-2004      Austria
# 2    ECHERER Raina A. Mercedes   echerer          0  1999-2004      Austria
# 3                  ETTL Harald      ettl          0  1999-2004      Austria
# 4          FLEMMING Marialiese  flemming          0  1999-2004      Austria
# ..                         ...       ...        ...        ...          ...
# 687               WYNN Terence      wynn          0  1999-2004         U.K.
# 688         DONNELLY Alan John  donnelly          0  1999-2004         U.K.
# 689              GREEN Pauline     green          0  1999-2004         U.K.
# 690            BOOTH Graham H.     booth          1  1999-2004         U.K.
# 691              EVANS Jillian     evans          0  1999-2004         U.K.
#
#     epg_code                                          epg_names  \
# 0          S    [Socialist Group, Party of European Socialists]
# 1          S    [Socialist Group, Party of European Socialists]
# 2          V       [Green Group, Greens/European Free Alliance]
# 3          S    [Socialist Group, Party of European Socialists]
# 4          E  [European People's Party, European People's Pa...
# ..       ...                                                ...
# 687        S    [Socialist Group, Party of European Socialists]
# 688        S    [Socialist Group, Party of European Socialists]
# 689        S    [Socialist Group, Party of European Socialists]
# 690        A  [Independents for a European of Nations, Europ...
# 691        V       [Green Group, Greens/European Free Alliance]
#
#      national_party_id                     national_party_name  \
# 0                 1005  Sozialdemokratische Partei Österreichs
# 1                 1005  Sozialdemokratische Partei Österreichs
# 2                 1002      Die Grünen – Die Grüne Alternative
# 3                 1005  Sozialdemokratische Partei Österreichs
# 4                 1004             Österreichische Volkspartei
# ..                 ...                                     ...
# 687               2404                            Labour Party
# 688               2404                            Labour Party
# 689               2404                            Labour Party
# 690               2409       United Kingdom Independence Party
# 691               2406            Plaid Cymru - Party of Wales
#
#     national_party_family
# 0                     Soc
# 1                     Soc
# 2                     Grn
# 3                     Soc
# 4                    CDem
# ..                    ...
# 687                   Soc
# 688                   Soc
# 689                   Soc
# 690               Anti-EU
# 691                   Reg
#
# [692 rows x 10 columns]

# %% [markdown]
# ## Data frame 2004-2009
# Now we do the same steps as above but for the 'Dataset MEPs EP 6 2004-2009.xlsx' file. It has a slightly different format and contains different encodings.

# %% [markdown]
# ###  Extract encodings of the data frame

# %%
national_party_2004 = pd.read_excel(file_names[2], sheet_name = 1)
national_party_dic_2004 = dict(zip(national_party_2004['ID'], national_party_2004['Name']))
#national_party_dic_2004

# %% [markdown]
# ### Assign a far-right or not far-right label to political parties
# Now we assign a label to each political parties code (SOC, S&D, etc.) telling if it's far right or not far right parties (0,1):
#
# * 1 - far-right
# * 0 - not far-right
#
# We assign these labels manually based on public information about these political parties.

# %%
df_2004 = pd.read_excel(file_names[2], sheet_name = 0)
df_2004
# Out:
#      nr          full_name country_name epg_name       id national party_id  \
# 0   NaN      BERGER, Maria      Austria      SOC   2285.0               206
# 1   NaN     BÖSCH, Herbert      Austria      SOC   2048.0               206
# 2   NaN       ETTL, Harald      Austria      SOC   2286.0               206
# 3   NaN      KARAS, Othmar      Austria   EPP-ED   4246.0               207
# 4   NaN  LEICHTFRIED, Jörg      Austria      SOC  28251.0               206
# ..   ..                ...          ...      ...      ...               ...
# 908 NaN   WILLMOTT, Glenis           UK      SOC  35743.0                57
# 909 NaN     SIMPSON, Brian           UK      SOC   1309.0                57
# 910 NaN     COLMAN, Trevor           UK  IND/DEM  94283.0                66
# 911 NaN  VILLIERS, Theresa           UK   EPP-ED   4520.0                54
# 912 NaN    RIBEIRO, Sérgio     Portugal  EUL/NGL    234.0                49
#
#     Newcomer/Amateur Rielected in the EP Rielected in the EP after interval  \
# 0                  n                   y                                NaN
# 1                  n                   y                                NaN
# 2                  n                   y                                NaN
# 3                  n                   y                                NaN
# 4                  y                 NaN                                NaN
# ..               ...                 ...                                ...
# 908                y                 NaN                                NaN
# 909                n                   y                                NaN
# 910                y                 NaN                                NaN
# 911                n                   y                                NaN
# 912                n                   y                                NaN
#
#      Number of past legislatures in the EP (not conisdering the 2004-2009)  \
# 0                                                  2.0
# 1                                                  2.0
# 2                                                  2.0
# 3                                                  1.0
# 4                                                  NaN
# ..                                                 ...
# 908                                                NaN
# 909                                                3.0
# 910                                                NaN
# 911                                                1.0
# 912                                                3.0
#
#     No  political experience/amateur                       National level  \
# 0                                NaN                                  NaN
# 1                                NaN                                   MP
# 2                                NaN        senior and/or junior minister
# 3                                NaN  member of national party leadership
# 4                                NaN  member of national party leadership
# ..                               ...                                  ...
# 908                                y                                  NaN
# 909                              NaN                                  NaN
# 910                              NaN  member of national party leadership
# 911                              NaN                                  NaN
# 912                              NaN                                  NaN
#
#      Code for previous national political roles Local level  \
# 0                                           NaN         NaN
# 1                                           1.0         NaN
# 2                                           3.0         NaN
# 3                                           4.0         NaN
# 4                                           NaN         NaN
# ..                                          ...         ...
# 908                                         NaN         NaN
# 909                                         NaN         NaN
# 910                                         4.0         NaN
# 911                                         NaN         NaN
# 912                                         NaN         NaN
#
#      Code for previous local political roles Gender   Role in the EP  \
# 0                                        NaN      f              NaN
# 1                                        NaN      m  committee chair
# 2                                        NaN      m              NaN
# 3                                        NaN      m              NaN
# 4                                       10.0      m              NaN
# ..                                       ...    ...              ...
# 908                                      NaN      f              NaN
# 909                                      NaN      m              NaN
# 910                                      NaN      m              NaN
# 911                                      NaN      f              NaN
# 912                                      NaN      m              NaN
#
#     Role in the party group notes  Report
# 0                       NaN   NaN       5
# 1                       NaN   NaN       5
# 2                       NaN   NaN       6
# 3                       NaN   NaN       6
# 4                       NaN   NaN       2
# ..                      ...   ...     ...
# 908                     NaN   NaN       0
# 909                     NaN   NaN       0
# 910                     NaN   NaN       0
# 911                     NaN   NaN       0
# 912                     NaN   NaN       1
#
# [913 rows x 20 columns]

# %%
df_2004['epg_name'].unique()
df_2004.loc[307,'epg_name'] = 'S&D'   # '\xa0\xa0\xa0\xa0\xa0S&D' ==> 'SOC'
df_2004.loc[535,'epg_name'] = 'na'    # nan -> 'na'
df_2004.loc[806,'epg_name'] = 'na'    # nan -> 'na'

far_right_dic_2004 = { 'SOC' : 0,
                      'S&D' : 0,
                      'EPP-ED' : 0,
                      'na' : 0,
                      'ALDE' : 0,
                      'G/EFA' : 0,
                      'EUL/NGL' : 0,
                      'IND/DEM' : 1,
                      'UEN' : 1}

# %%
party_names_dic_2004 = {'SOC' : "SOC",  # ? we are not 100% sure what SOC stands for, but we assume these are not far right parties
                      'S&D' : "The Progressive Alliance of Socialists and Democrats",
                      'EPP-ED' : "European People's Party Group and European Democrats",
                      'na' : 'NA',
                      'ALDE' : "Alliance of Liberals and Democrats for Europe Party",
                      'G/EFA' : "The Greens/European Free Alliance",
                      'EUL/NGL' : "The Left in the European Parliament",
                      'IND/DEM' : "Independence/Democracy",
                      'UEN' : "Union for Europe of the Nations"}

# %% [markdown]
# ### Transform the data frame to new format
# We create a new data frame that contains names of the European Parliament members, far-right vs not far-right labels, and other information that might be useful for the analysis.

# %%
df_2004 = df_2004[['full_name', 'country_name', 'epg_name', 'national party_id']]
df_2004.loc[:,['surname']] = [x.split(",")[0].lower() for x in df_2004['full_name']] # contains diacritics
df_2004.loc[:,['full_name']] = df_2004['full_name'].apply(lambda x: x.replace(',', ''))
df_2004.loc[:,['far_right']] = [far_right_dic_2004[x] for x in df_2004['epg_name']]
df_2004.loc[:,['years']] = file_names[2][-14:-5]

#manually correct data entry mistakes
df_2004.loc[307,'national party_id'] = 151    #Dagmar Reichenbach 
# "\xa0\xa0\xa0\xa0\xa0Social Democratic Party" -> 'Socialdemokratiet'

df_2004.loc[:,['national_party_name']] = [national_party_dic_2004[x] for x in df_2004['national party_id']]
df_2004.loc[:,['epg_names']] = [party_names_dic_2004[x] for x in df_2004['epg_name']]
df_2004.rename(columns = {'epg_name':'epg_code',
                          'national party_id' : 'national_party_id'              
                         }, inplace = True)
df_2004
# Out:
# /tmp/ipykernel_5732/2603640357.py:4: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_2004.loc[:,['far_right']] = [far_right_dic_2004[x] for x in df_2004['epg_name']]
#             full_name country_name epg_code national_party_id      surname  \
# 0        BERGER Maria      Austria      SOC               206       berger
# 1       BÖSCH Herbert      Austria      SOC               206        bösch
# 2         ETTL Harald      Austria      SOC               206         ettl
# 3        KARAS Othmar      Austria   EPP-ED               207        karas
# 4    LEICHTFRIED Jörg      Austria      SOC               206  leichtfried
# ..                ...          ...      ...               ...          ...
# 908   WILLMOTT Glenis           UK      SOC                57     willmott
# 909     SIMPSON Brian           UK      SOC                57      simpson
# 910     COLMAN Trevor           UK  IND/DEM                66       colman
# 911  VILLIERS Theresa           UK   EPP-ED                54     villiers
# 912    RIBEIRO Sérgio     Portugal  EUL/NGL                49      ribeiro
#
#      far_right      years                                national_party_name  \
# 0            0  2004-2009             Sozialdemokratische Partei Österreichs
# 1            0  2004-2009             Sozialdemokratische Partei Österreichs
# 2            0  2004-2009             Sozialdemokratische Partei Österreichs
# 3            0  2004-2009  Österreichische Volkspartei - Liste Ursula Ste...
# 4            0  2004-2009             Sozialdemokratische Partei Österreichs
# ..         ...        ...                                                ...
# 908          0  2004-2009                                       Labour Party
# 909          0  2004-2009                                       Labour Party
# 910          1  2004-2009                              UK Independence Party
# 911          0  2004-2009                    Conservative and Unionist Party
# 912          0  2004-2009           Coligação Democrática Unitária (PCP-PEV)
#
#                                              epg_names
# 0                                                  SOC
# 1                                                  SOC
# 2                                                  SOC
# 3    European People's Party Group and European Dem...
# 4                                                  SOC
# ..                                                 ...
# 908                                                SOC
# 909                                                SOC
# 910                             Independence/Democracy
# 911  European People's Party Group and European Dem...
# 912                The Left in the European Parliament
#
# [913 rows x 9 columns]

# %% [markdown]
# ##  Data frame 2009-2014
# Now we do the same steps as above but for a 'Dataset MEPs 7EP 2009-2014.xlsx' file. It has a slightly different format and contains different encodings.

# %% [markdown]
# ### Assign a far-right or not far-right label to political parties
# We assign a label to each political parties code (NI, S&D, etc.) telling if it's far right or not far right parties (0,1):
#
# * 1 - far-right
# * 0 - not far-right
#
# We assign these labels manually based on public information about these political parties.

# %%
df_2009 = pd.read_excel(file_names[3], sheet_name = 0)
df_2009
# Out:
#                 fullName  country politicalGroup  \
# 0     Martin Ehrenhauser  Austria             NI
# 1        Karin Kadenbach  Austria            S&D
# 2           Othmar Karas  Austria            EPP
# 3    Elisabeth Köstinger  Austria            EPP
# 4       Jörg Leichtfried  Austria            S&D
# ..                   ...      ...            ...
# 811          Jean Roatta   France            EPP
# 812          Yves Cochet   France          G–EFA
# 813        Nils TORVALDS  Finland           ALDE
# 814      Isabelle THOMAS   France            S&D
# 815   KAUPPI, Piia-Noora  Finland         EPP-ED
#
#                    national Party Newcomer in the EP Rielected in the EP  \
# 0        Hans-Peter Martin's List                  y                 NaN
# 1         Social Democratic Party                  y                 NaN
# 2                  People's Party                  n                   y
# 3                  People's Party                  y                 NaN
# 4         Social Democratic Party                  N                   Y
# ..                            ...                ...                 ...
# 811  Union for a Popular Movement                  y                 NaN
# 812                Europe Ecology                  y                 NaN
# 813           Svenska folkpartiet                  Y                 NaN
# 814              Parti socialiste                  Y                 NaN
# 815                           216                  n                   y
#
#     Rielected in the EP after interval  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 811                                NaN
# 812                                NaN
# 813                                NaN
# 814                                NaN
# 815                                NaN
#
#      Number of past legislatures in the EP (not conisdering the 2009-2014)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  2.0
# 3                                                  NaN
# 4                                                  1.0
# ..                                                 ...
# 811                                                NaN
# 812                                                NaN
# 813                                                NaN
# 814                                                NaN
# 815                                                2.0
#
#     No political experience/Amateur                       National level  \
# 0                                 y                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN  member of national party leadership
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
# ..                              ...                                  ...
# 811                             NaN                                   MP
# 812                             NaN                                   MP
# 813                             NaN  member of national party leadership
# 814                             NaN  member of national party leadership
# 815                             NaN  member of national party leadership
#
#      Code for previous national political roles  \
# 0                                           NaN
# 1                                           NaN
# 2                                           4.0
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 811                                         1.0
# 812                                         1.0
# 813                                         NaN
# 814                                         4.0
# 815                                         4.0
#
#                              Local level  \
# 0                                    NaN
# 1          Member of regional parliament
# 2                                    NaN
# 3    member of regional party leadership
# 4    member of regional party leadership
# ..                                   ...
# 811                                  NaN
# 812                                  NaN
# 813                       council member
# 814        Member of regional parliament
# 815                       council member
#
#      ode for previous local politcal roles gender  Role in the EP  \
# 0                                      NaN      m             NaN
# 1                                      5.0      f             NaN
# 2                                      NaN      m  vice president
# 3                                      NaN      f             NaN
# 4                                     10.0      m             NaN
# ..                                     ...    ...             ...
# 811                                    NaN      m             NaN
# 812                                    NaN      m             NaN
# 813                                    9.0      M             NaN
# 814                                    5.0      F             NaN
# 815                                    9.0      f             NaN
#
#     Role in the party group  Reports Notes
# 0                       NaN      2.0   NaN
# 1                       NaN      1.0   NaN
# 2                vice chair      5.0   NaN
# 3      member of the bureau      2.0   NaN
# 4                vice chair      8.0   NaN
# ..                      ...      ...   ...
# 811                     NaN      0.0   NaN
# 812                     NaN      0.0   NaN
# 813                     NaN      1.0   NaN
# 814                     NaN      2.0   NaN
# 815                     NaN      2.0   NaN
#
# [816 rows x 18 columns]

# %%
df_2009['politicalGroup'].unique()

far_right_dic_2009 = {
    'NI' : 0,
    'S&D' : 0, 
    'EPP' : 0,
    'G–EFA' : 0,
    'ECR' : 0,
    'ALDE' : 0,
    'NI/EFD' : 1,
    'EUL–NGL' : 0,
    'EFD' : 1,
    'EUL-NGL' : 0,
    'EUL/NGL' : 0,
    'G-EFA' : 0,
    'EPP-ED' : 0}

# %%
political_party_names_2009 = {
    'NI' : "Non-Inscrits",
    'S&D' : "The Progressive Alliance of Socialists and Democrats", 
    'EPP' : "European People's Party Group",
    'G–EFA' : "The Greens/European Free Alliance",
    'ECR' : "The European Conservatives and Reformists Group",
    'ALDE' : "Alliance of Liberals and Democrats for Europe Party",
    'NI/EFD' : "Non-Inscrits / Europe of Freedom and Democracy",   ## only Frank Vanhecke
    'EUL–NGL' : "The Left in the European Parliament",
    'EFD' : "Europe of Freedom and Democracy",
    'EUL-NGL' : "The Left in the European Parliament",
    'EUL/NGL' : "The Left in the European Parliament",
    'G-EFA' : "The Greens/European Free Alliance",
    'EPP-ED' : "European People's Party Group / European Democrats"}

# %% [markdown]
# ### Transform the data frame to new format
# We create a new data frame that contains names of the European Parliament members, far-right vs not far-right labels, and other information that might be useful for the analysis.

# %%
df_2009 = df_2009[['fullName', 'country', 'politicalGroup', 'national Party']]
df_2009.loc[:,['surname']] = [x.split(" ")[1].lower() for x in df_2009['fullName']] 
df_2009.loc[:,['far_right']] = [far_right_dic_2009[x] for x in df_2009['politicalGroup']]
df_2009.loc[:,['years']] = file_names[3][-14:-5]
df_2009.loc[:,['epg_names']] = [political_party_names_2009[x] for x in df_2009['politicalGroup']]
df_2009.rename(columns = {'country':'country_name',
                          'fullName' : 'full_name',
                          'politicalGroup': 'epg_code',
                          'national Party' : 'national_party_name'                    
                         }, inplace = True)
df_2009
# Out:
# /tmp/ipykernel_5732/3354704225.py:3: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_2009.loc[:,['far_right']] = [far_right_dic_2009[x] for x in df_2009['politicalGroup']]
#                full_name country_name epg_code           national_party_name  \
# 0     Martin Ehrenhauser      Austria       NI      Hans-Peter Martin's List
# 1        Karin Kadenbach      Austria      S&D       Social Democratic Party
# 2           Othmar Karas      Austria      EPP                People's Party
# 3    Elisabeth Köstinger      Austria      EPP                People's Party
# 4       Jörg Leichtfried      Austria      S&D       Social Democratic Party
# ..                   ...          ...      ...                           ...
# 811          Jean Roatta       France      EPP  Union for a Popular Movement
# 812          Yves Cochet       France    G–EFA                Europe Ecology
# 813        Nils TORVALDS      Finland     ALDE           Svenska folkpartiet
# 814      Isabelle THOMAS       France      S&D              Parti socialiste
# 815   KAUPPI, Piia-Noora      Finland   EPP-ED                           216
#
#          surname  far_right      years  \
# 0    ehrenhauser          0  2009-2014
# 1      kadenbach          0  2009-2014
# 2          karas          0  2009-2014
# 3      köstinger          0  2009-2014
# 4    leichtfried          0  2009-2014
# ..           ...        ...        ...
# 811       roatta          0  2009-2014
# 812       cochet          0  2009-2014
# 813     torvalds          0  2009-2014
# 814       thomas          0  2009-2014
# 815   piia-noora          0  2009-2014
#
#                                              epg_names
# 0                                         Non-Inscrits
# 1    The Progressive Alliance of Socialists and Dem...
# 2                        European People's Party Group
# 3                        European People's Party Group
# 4    The Progressive Alliance of Socialists and Dem...
# ..                                                 ...
# 811                      European People's Party Group
# 812                  The Greens/European Free Alliance
# 813  Alliance of Liberals and Democrats for Europe ...
# 814  The Progressive Alliance of Socialists and Dem...
# 815  European People's Party Group / European Democ...
#
# [816 rows x 8 columns]

# %% [markdown]
# ## Concatenate data frames

# %%
concatenated = pd.concat([df_1994, df_1999, df_2004, df_2009])
concatenated.reset_index(drop = True, inplace = True)
concatenated
# Out:
#                     full_name     surname  far_right      years country_name  \
# 0              ADAM Gordon J.        adam          0  1994-1999         U.K.
# 1          AELVOET Magda G.H.     aelvoet          0  1994-1999      Belgium
# 2     AGLIETTA Maria Adelaide    aglietta          0  1994-1999        Italy
# 3                 AHERN Nuala       ahern          0  1994-1999      Ireland
# 4           AHLQVIST Birgitta    ahlqvist          0  1994-1999       Sweden
# ...                       ...         ...        ...        ...          ...
# 3158              Jean Roatta      roatta          0  2009-2014       France
# 3159              Yves Cochet      cochet          0  2009-2014       France
# 3160            Nils TORVALDS    torvalds          0  2009-2014      Finland
# 3161          Isabelle THOMAS      thomas          0  2009-2014       France
# 3162       KAUPPI, Piia-Noora  piia-noora          0  2009-2014      Finland
#
#      epg_code                                          epg_names  \
# 0           S    [Socialist Group, Party of European Socialists]
# 1           V       [Green Group, Greens/European Free Alliance]
# 2           V       [Green Group, Greens/European Free Alliance]
# 3           V       [Green Group, Greens/European Free Alliance]
# 4           S    [Socialist Group, Party of European Socialists]
# ...       ...                                                ...
# 3158      EPP                      European People's Party Group
# 3159    G–EFA                  The Greens/European Free Alliance
# 3160     ALDE  Alliance of Liberals and Democrats for Europe ...
# 3161      S&D  The Progressive Alliance of Socialists and Dem...
# 3162   EPP-ED  European People's Party Group / European Democ...
#
#      national_party_id                                national_party_name  \
# 0                 2404                                       Labour Party
# 1                 1101              Anders gaan arbeiden, leven en vrijen
# 2                 1609  Verdi Arcobaleno / Federazione dei Verdi / Ver...
# 3                 2203                                        Green Party
# 4                 2306                 Socialdemokratiska arbetarepartiet
# ...                ...                                                ...
# 3158               NaN                       Union for a Popular Movement
# 3159               NaN                                     Europe Ecology
# 3160               NaN                                Svenska folkpartiet
# 3161               NaN                                   Parti socialiste
# 3162               NaN                                                216
#
#      national_party_family
# 0                      Soc
# 1                      Grn
# 2                      Grn
# 3                      Grn
# 4                      Soc
# ...                    ...
# 3158                   NaN
# 3159                   NaN
# 3160                   NaN
# 3161                   NaN
# 3162                   NaN
#
# [3163 rows x 10 columns]

# %% [markdown]
# Check how many far-right politicians are in the data frame

# %%
# concatenated[concatenated['far_right'] == 1]  #311

# %% [markdown]
# Check what names repeat in the data frame

# %%
#concatenated['full_name'].value_counts()

# %% [markdown]
# Save the final data frame into 'MEP_dataframe.csv', you can use this data frame in [data_cleaning_preprocessing.ipynb](data_cleaning_preprocessing.ipynb)

# %%
concatenated.to_csv(path_or_buf = os.path.join(path, 'MEP_dataframe.csv'))
