# %% [markdown]
# # Loading Data

# %%
import pandas as pd
import numpy as np
import nltk
import os
import re
import string

# %%
#sample dataframe
data = {
    "speaker_id": [2],
    "name": ["Evans, Robert J"],
    "language": ["en"],
    "party_affiliation": ["unknown"],
    "paragraph_text": ["Madam President, on a point of order. You will be aware from the press and television that there have been a number of bomb explosions and killings in Sri Lanka. One of the people assassinated very recently in Sri Lanka was Mr Kumar Ponnambalam, who had visited the European Parliament just a few months ago. Would it be appropriate for you, Madam President, to write a letter to the Sri Lankan President expressing Parliament's regret at his and the other violent deaths in Sri Lanka and urging her to do everything she possibly can to seek a peaceful reconciliation to a very difficult situation?"],
    "date": ["00-01-17"],
    "right_wing": [0]
}

df = pd.DataFrame(data)
df.head()
# Out:
#    speaker_id             name language party_affiliation  \
# 0           2  Evans, Robert J       en           unknown
#
#                                       paragraph_text      date  right_wing
# 0  Madam President, on a point of order. You will...  00-01-17           0

# %%
path = f"{os.getcwd()}/data_sample"

# %%
corpus = {}
for i in os.listdir(path):
    corpus[i] = nltk.data.load(f'{path}/{i}', format='raw')

# %%
corpus2 = pd.DataFrame.from_dict([corpus]).T

# %%
for index, i in enumerate(corpus2[0]):
    corpus2.iloc[index][0] = i.decode('UTF-8')

# %%
corpus2
# Out:
#                                                                  0
# ep-00-06-13.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-01-18.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-14.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-01-19.txt  <CHAPTER ID=5>\nMiddle East peace process (con...
# ep-00-06-14.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Presiden...
# ep-00-01-21.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-11.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-03-30.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-10.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-06-15.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="NL" ...
# ep-00-04-12.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-13.txt  <CHAPTER ID=1>\nPrinciples for recording taxes...
# ep-00-06-16.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Helmer">...
# ep-00-02-15.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-09-08.txt  <CHAPTER ID=1>\nTribute\n<SPEAKER ID=1 NAME="P...
# ep-00-09-20.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-21.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="ES" ...
# ep-00-02-14.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-02-16.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-02-02.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-10-02.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-10-03.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Presiden...
# ep-00-02-03.txt  <CHAPTER ID=1>\nEnd-of-life vehicles\n<SPEAKER...
# ep-00-02-17.txt  <CHAPTER ID=1>\nResumption of the sitting\n<SP...
# ep-00-05-19.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-05-18.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="IT" ...
# ep-00-05-15.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-07-04.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-07-05.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-05-16.txt  <CHAPTER ID=1>\nDecision on urgent procedure\n...
# ep-00-07-07.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-07-06.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-05-17.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-05-03.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-07.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="DE" ...
# ep-00-07-03.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-06.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="EL" ...
# ep-00-05-04.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-09-04.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-05.txt  <CHAPTER ID=1>\nWelcome\n<SPEAKER ID=1 NAME="P...
# ep-00-02-18.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-03-17.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-03-02.txt  <CHAPTER ID=2>\nShipwreck of the Erika\n<SPEAK...
# ep-00-03-16.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Presiden...
# ep-00-03-14.txt  <CHAPTER ID=1>\nOpening of the session\n<SPEAK...
# ep-00-03-29.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-03-15.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="NL" ...
# ep-00-03-01.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-01-17.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-03-13.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...

# %%
#text = corpus2[0][7]
text = corpus2[0][25]

# %%
#text

# %%
chap_split = text.split("<CHAP")

# %%
chap_split = [i for i in chap_split if i != '']
#chap_split

# %%
len(chap_split)
# Out:
# 15

# %%
spea_split = []
for i in chap_split:
    spea_split.append(i.split("SPEA"))

# %%
#spea_split

# %%
j = 0
for i in spea_split:
    print(len(i))
    j += len(i)
# Out:
# 5
# 30
# 16
# 14
# 83
# 10
# 2
# 29
# 2
# 13
# 9
# 35
# 11
# 12
# 10

# %%
j
# Out:
# 281

# %%
test_corp = pd.DataFrame(spea_split).T
test_corp
# Out:
#                                                    0   \
# 0                                      TER ID=0>\n\n<
# 1   KER ID=1 LANGUAGE="IT" NAME="Buttiglione">\nMa...
# 2   KER ID=2 LANGUAGE="IT" NAME="Tajani">\nMadam P...
# 3   KER ID=3 LANGUAGE="IT" NAME="Napoletano">\nMad...
# 4   KER ID=4 NAME="President">\nThank you, Mrs Nap...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    1   \
# 0           TER ID=1>\nStatements by the President\n<
# 1   KER ID=5 NAME="President">\nI have two stateme...
# 2   KER ID=6 NAME="Morgan">\nMadam President, it i...
# 3   KER ID=7 NAME="President">\nMy second statemen...
# 4   KER ID=8 LANGUAGE="ES" NAME="Barón Crespo">\nM...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    2   \
# 0                       TER ID=2>\nEqual treatment\n<
# 1   KER ID=34 NAME="President">\nThe next item is ...
# 2   KER ID=35 LANGUAGE="NL" NAME="Oostlander">\nMa...
# 3   KER ID=36 NAME="Cox">\nMadam President, on a p...
# 4   KER ID=37 NAME="President">\nThank you, Mr Cox...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    3   \
# 0                  TER ID=3>\nTrafficking in women\n<
# 1   KER ID=49 LANGUAGE="NL" NAME="Sörensen">\nMr P...
# 2   KER ID=50 NAME="Roure">\n. (FR) Mr President, ...
# 3   KER ID=51 LANGUAGE="NL" NAME="Martens">\nMr Pr...
# 4   KER ID=52 LANGUAGE="ES" NAME="Valenciano Martí...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    4   \
# 0                                  TER ID=4>\nVote\n<
# 1   KER ID=62 NAME="Purvis">\nMr President, I am v...
# 2   KER ID=63 NAME="President">\nMr Purvis, the wa...
# 3   KER ID=64 NAME="Ahern">\nMr President, the res...
# 4   KER ID=65 NAME="President">\nLet us proceed wi...
# ..                                                ...
# 78  KER ID=139 NAME="Perry">\n - The British Conse...
# 79  KER ID=140 NAME="Scallon">\n - According to th...
# 80  KER ID=141 NAME="Thomas-Mauro">\nThe UEN Group...
# 81  KER ID=142 NAME="Vachetta">\nThe report on the...
# 82  KER ID=143 NAME="President">\nThat concludes t...
#
#                                                    5   \
# 0                       TER ID=5>\nEqual treatment\n<
# 1   KER ID=144 NAME="President">\nThe next item is...
# 2   KER ID=145 LANGUAGE="NL" NAME="Buitenweg">\nMr...
# 3   KER ID=146 LANGUAGE="PT" NAME="Ribeiro e Castr...
# 4   KER ID=147 NAME="President">\nI note what you ...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    6   \
# 0                               TER ID=6>\nWelcome\n<
# 1   KER ID=153 NAME="President">\nI have just been...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    7   \
# 0        TER ID=7>\nEqual treatment (continuation)\n<
# 1   KER ID=154 NAME="Ludford">\nI am delighted to ...
# 2   KER ID=155 NAME="Boumediène-Thiery">\nMr Presi...
# 3   KER ID=156 LANGUAGE="DE" NAME="Posselt">\nMr P...
# 4   KER ID=157 NAME="President">\nMr Posselt, we a...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    8   \
# 0             TER ID=8>\nTopical and urgent debate\n<
# 1   KER ID=182 NAME="President">\nThe next item is...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    9   \
# 0                          TER ID=9>\nSierra Leone\n<
# 1   KER ID=183 NAME="President">\nThe first item i...
# 2   KER ID=184 LANGUAGE="NL" NAME="Van den Bos">\n...
# 3   KER ID=185 LANGUAGE="ES" NAME="Sauquillo Pérez...
# 4   KER ID=186 LANGUAGE="NL" NAME="Van Hecke, Joha...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    10  \
# 0                            TER ID=10>\nSri Lanka\n<
# 1   KER ID=195 NAME="President">\nThe next item is...
# 2   KER ID=196 NAME="Foster">\nMr President, the r...
# 3   KER ID=197 NAME="Lambert">\nThe issue of the p...
# 4   KER ID=198 NAME="Heaton-Harris">\nMr President...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    11  \
# 0                         TER ID=11>\nHuman rights\n<
# 1   KER ID=203 NAME="President">\nThe next item is...
# 2   KER ID=204 LANGUAGE="SV" NAME="Thors">\nMr Pre...
# 3   KER ID=205 LANGUAGE="DE" NAME="Posselt">\nMr P...
# 4   KER ID=206 NAME="Isler Béguin">\nMr President,...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    12  \
# 0                                 TER ID=12>\nVote\n<
# 1   KER ID=237 LANGUAGE="NL" NAME="Meijer">\nMr Pr...
# 2   KER ID=238 LANGUAGE="IT" NAME="Fatuzzo">\nMr P...
# 3   KER ID=239 NAME="Berthu">\nThe Commission' s p...
# 4   KER ID=240 NAME="Dehousse">\nI was going to vo...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    13  \
# 0   TER ID=13>\nTrafficking in women (continuation...
# 1   KER ID=247 NAME="President">\nThe next item is...
# 2   KER ID=248 LANGUAGE="ES" NAME="Avilés Perea">\...
# 3   KER ID=249 LANGUAGE="SV" NAME="Theorin">\nMr P...
# 4   KER ID=250 LANGUAGE="SV" NAME="Paulsen">\nMr P...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
#                                                    14
# 0   TER ID=14>\nReadmission of third country natio...
# 1   KER ID=258 NAME="President">\nThe next item is...
# 2   KER ID=259 LANGUAGE="EL" NAME="Êaramanou">\nMr...
# 3   KER ID=260 LANGUAGE="DE" NAME="Echerer">\nMr P...
# 4   KER ID=261 LANGUAGE="ES" NAME="Palacio Vallele...
# ..                                                ...
# 78                                               None
# 79                                               None
# 80                                               None
# 81                                               None
# 82                                               None
#
# [83 rows x 15 columns]

# %%
d = {}
counter = 0
for text in spea_split:
    d[counter] = []
    for contribution in text:
        d[counter].append(contribution)
    counter += 1

# %%
spea_split[2][0].partition('ID=')[2].partition('>\n')[0]
# Out:
# '2'

# %%
d = {}

for chapter in spea_split:
    #careful: we assume that the chapter title is contained in the first element of the list 'chapter'
    d[chapter[0].partition('ID=')[2].partition('>\n')[0]] = []
    for contribution in chapter:
        d[chapter[0].partition('ID=')[2].partition('>\n')[0]].append(contribution)

# %%
entries = []
chapter = []
for i in d:
    entries.extend(d[i])
    for k in range(len(d[i])):
        chapter.append(i)

# %%
titles = []
for i in d:
    titles.append(d[i][0])

# %%
results = pd.DataFrame({'contribution': entries,'chapter': chapter})
results
# Out:
#                                           contribution chapter
# 0                                       TER ID=0>\n\n<       0
# 1    KER ID=1 LANGUAGE="IT" NAME="Buttiglione">\nMa...       0
# 2    KER ID=2 LANGUAGE="IT" NAME="Tajani">\nMadam P...       0
# 3    KER ID=3 LANGUAGE="IT" NAME="Napoletano">\nMad...       0
# 4    KER ID=4 NAME="President">\nThank you, Mrs Nap...       0
# ..                                                 ...     ...
# 276  KER ID=262 LANGUAGE="DE" NAME="Berger">\nMr Pr...      14
# 277  KER ID=263 LANGUAGE="SV" NAME="Thors">\nMr Pre...      14
# 278  KER ID=264 NAME="Berthu">\nMr President, the K...      14
# 279  KER ID=265 NAME="Vitorino">\nMr President, the...      14
# 280  KER ID=266 NAME="President">\nThat concludes t...      14
#
# [281 rows x 2 columns]

# %%
chap_titles = {}
for i in results.contribution:
    if 'TER ID=' in i:
        chap_titles[i.partition('ID=')[2].partition('>\n')[0]] = i.partition('>\n')[2].partition('\n<')[0]

# %%
chap_titles
# Out:
# {'0': '',
#  '1': 'Statements by the President',
#  '2': 'Equal treatment',
#  '3': 'Trafficking in women',
#  '4': 'Vote',
#  '5': 'Equal treatment',
#  '6': 'Welcome',
#  '7': 'Equal treatment (continuation)',
#  '8': 'Topical and urgent debate',
#  '9': 'Sierra Leone',
#  '10': 'Sri Lanka',
#  '11': 'Human rights',
#  '12': 'Vote',
#  '13': 'Trafficking in women (continuation)',
#  '14': 'Readmission of third country nationals'}

# %%
results['chapter'] = results['chapter'].astype(str)

results['chapter_title'] = results['chapter'].map(chap_titles)

# %%
results = results.reset_index(drop = True)

# %% [markdown]
# hello

# %%
len(results.chapter.unique())
# Out:
# 15

# %%
results = results[results.contribution.str.contains('KER ID')]

# %%
sp_id = {}
for i in results.contribution:
    sp_id[i.partition('KER ID=')[2].partition(' ')[0]] = i.partition('NAME=\"')[2].partition('\">')[0]

# %%
results['contribution_id'] = sp_id.keys()
results
# Out:
#                                           contribution chapter  \
# 1    KER ID=1 LANGUAGE="IT" NAME="Buttiglione">\nMa...       0
# 2    KER ID=2 LANGUAGE="IT" NAME="Tajani">\nMadam P...       0
# 3    KER ID=3 LANGUAGE="IT" NAME="Napoletano">\nMad...       0
# 4    KER ID=4 NAME="President">\nThank you, Mrs Nap...       0
# 6    KER ID=5 NAME="President">\nI have two stateme...       1
# ..                                                 ...     ...
# 276  KER ID=262 LANGUAGE="DE" NAME="Berger">\nMr Pr...      14
# 277  KER ID=263 LANGUAGE="SV" NAME="Thors">\nMr Pre...      14
# 278  KER ID=264 NAME="Berthu">\nMr President, the K...      14
# 279  KER ID=265 NAME="Vitorino">\nMr President, the...      14
# 280  KER ID=266 NAME="President">\nThat concludes t...      14
#
#                               chapter_title contribution_id
# 1                                                         1
# 2                                                         2
# 3                                                         3
# 4                                                         4
# 6               Statements by the President               5
# ..                                      ...             ...
# 276  Readmission of third country nationals             262
# 277  Readmission of third country nationals             263
# 278  Readmission of third country nationals             264
# 279  Readmission of third country nationals             265
# 280  Readmission of third country nationals             266
#
# [266 rows x 4 columns]

# %%
results['speaker_name'] = results['contribution_id'].map(sp_id)
results
# Out:
#                                           contribution chapter  \
# 1    KER ID=1 LANGUAGE="IT" NAME="Buttiglione">\nMa...       0
# 2    KER ID=2 LANGUAGE="IT" NAME="Tajani">\nMadam P...       0
# 3    KER ID=3 LANGUAGE="IT" NAME="Napoletano">\nMad...       0
# 4    KER ID=4 NAME="President">\nThank you, Mrs Nap...       0
# 6    KER ID=5 NAME="President">\nI have two stateme...       1
# ..                                                 ...     ...
# 276  KER ID=262 LANGUAGE="DE" NAME="Berger">\nMr Pr...      14
# 277  KER ID=263 LANGUAGE="SV" NAME="Thors">\nMr Pre...      14
# 278  KER ID=264 NAME="Berthu">\nMr President, the K...      14
# 279  KER ID=265 NAME="Vitorino">\nMr President, the...      14
# 280  KER ID=266 NAME="President">\nThat concludes t...      14
#
#                               chapter_title contribution_id speaker_name
# 1                                                         1  Buttiglione
# 2                                                         2       Tajani
# 3                                                         3   Napoletano
# 4                                                         4    President
# 6               Statements by the President               5    President
# ..                                      ...             ...          ...
# 276  Readmission of third country nationals             262       Berger
# 277  Readmission of third country nationals             263        Thors
# 278  Readmission of third country nationals             264       Berthu
# 279  Readmission of third country nationals             265     Vitorino
# 280  Readmission of third country nationals             266    President
#
# [266 rows x 5 columns]

# %%
def lang_extracter(x):
    return x.partition('LANGUAGE=\"')[2].partition('\"')[0]

# %%
results['language'] = results['contribution'].apply(lang_extracter)

# %%
def id_extracter(x):
    return 'year-month-day-'+x

# %%
results['contribution_id'] = results['contribution_id'].apply(id_extracter)

# %%
results
# Out:
#                                           contribution chapter  \
# 1    KER ID=1 LANGUAGE="IT" NAME="Buttiglione">\nMa...       0
# 2    KER ID=2 LANGUAGE="IT" NAME="Tajani">\nMadam P...       0
# 3    KER ID=3 LANGUAGE="IT" NAME="Napoletano">\nMad...       0
# 4    KER ID=4 NAME="President">\nThank you, Mrs Nap...       0
# 6    KER ID=5 NAME="President">\nI have two stateme...       1
# ..                                                 ...     ...
# 276  KER ID=262 LANGUAGE="DE" NAME="Berger">\nMr Pr...      14
# 277  KER ID=263 LANGUAGE="SV" NAME="Thors">\nMr Pre...      14
# 278  KER ID=264 NAME="Berthu">\nMr President, the K...      14
# 279  KER ID=265 NAME="Vitorino">\nMr President, the...      14
# 280  KER ID=266 NAME="President">\nThat concludes t...      14
#
#                               chapter_title     contribution_id speaker_name  \
# 1                                              year-month-day-1  Buttiglione
# 2                                              year-month-day-2       Tajani
# 3                                              year-month-day-3   Napoletano
# 4                                              year-month-day-4    President
# 6               Statements by the President    year-month-day-5    President
# ..                                      ...                 ...          ...
# 276  Readmission of third country nationals  year-month-day-262       Berger
# 277  Readmission of third country nationals  year-month-day-263        Thors
# 278  Readmission of third country nationals  year-month-day-264       Berthu
# 279  Readmission of third country nationals  year-month-day-265     Vitorino
# 280  Readmission of third country nationals  year-month-day-266    President
#
#     language
# 1         IT
# 2         IT
# 3         IT
# 4
# 6
# ..       ...
# 276       DE
# 277       SV
# 278
# 279
# 280
#
# [266 rows x 6 columns]

# %%
results.contribution[30]
# Out:
# 'KER ID=29 LANGUAGE="DE" NAME="Poettering">\nMadam President, I am sorry I need to ask to speak again, but we cannot vote on anything at all here today, because we have clear and proper procedures. If we refer a matter to a committee, then we must have a basis for doing so, that is to say we need a document defining that referral. We do not have such a document. That is why I urge you not to hold a vote on this matter now in any way whatsoever.\n<P>\n\n<'

# %%
def contribution_extracter(x):
    x = x.partition('>\n')[2].partition('\n\n<')[0]
    x = x.replace('\n<P>\n', ' ')
    return x

# %%
results['contribution_text'] = results['contribution'].apply(contribution_extracter)

# %%
results.contribution_text[52]
# Out:
# "Mr President, Mrs Diamantopoulou, ladies and gentlemen, first of all, I would like to thank everyone who has worked on this report, that is to say, all collaborators, but also the people from the Committee on Women' s Rights and Equal Opportunities and the interpreters, who have worked very hard. This report is also a reaction to the excellent communication by the Committee on new measures to fight trafficking in women. By way of preparing for the report, the Committee on Women' s Rights and Equal Opportunities organised a public hearing which involved experts and the presence of a victim who came to give her story. A delegation of this committee, together with Mrs Diamantopoulou, visited a shelter for victims of trafficking in people. Moreover, the Ministries of Foreign Affairs of Member States and candidate countries received a questionnaire on how they tackle trafficking in women, the results of which will be made available to the European Commission. The report primarily aims to fight trafficking in women, but also in children and men, that is to say in people in general. Trafficking in children does exist, but they are used as adults. Men, too, are victims of trafficking in people and are sexually abused. In fact, the sex industry is not the only market on which the victims of such trafficking are sold. In Belgium, 40 percent of the victims end up on the labour market, in the textile, hotel and catering and fruit-picking industries, bakeries and the construction industry, or as house staff or au-pair girls, obliged to work as slaves in degrading conditions. Victims are also recruited for the marriage market, as well as to sports clubs and football clubs. According to estimates by the United Nations and the International Organisation for Migration, the IOM, every year four million people throughout the world fall victim to trafficking, 500 000 of whom end up in Europe. All the signs are there that the number of victims is rising and that the influx from Central and Eastern European countries has exceeded the existing stream from Africa, Latin America, the Caribbean and Asia. In a report by the United Nations, it is stressed that trafficking in people is one of the fastest growing forms of organised crime. The huge profits and relative safety for the perpetrators who generate this type of crime will undoubtedly have something to do with this. The penalties for smuggling narcotics, for example, are far higher than those for trafficking in women. Victims are often unable to speak out on account of the illegal situation they are in. Since there are clear indications that these problems are developing within the framework of international networks, it is important that these problems are addressed and tackled at European level. In order to tackle trafficking in people adequately, we first of all need a clear definition of trafficking in people. Priority must also be given to the fight against organised networks which are not only involved in trafficking in people but which are also involved in all kinds of other criminal activity, such as the trade in narcotics, arms and such like. I therefore applaud the new Community initiatives concerning money laundering where the income from trafficking in women plays a major role. Various initiatives have already been taken at European level. Efforts to increase public awareness have got off to a good start in the form of activities on the part of Interpol and Europol, initiatives in every individual Member State, Habitat projects, etc. However, the harmonisation of the different national legislations in this field and the ensuing discrepancies in methods of investigation and prosecution have to be tackled at European level as a matter of priority. From a survey organised in connection with this report, it is quite clear that there are considerable discrepancies in this sphere between the Member States and between one candidate country and another. Some countries which have strict legisl ...

# %%
results.contribution[52]
# Out:
# 'KER ID=49 LANGUAGE="NL" NAME="Sörensen">\nMr President, Mrs Diamantopoulou, ladies and gentlemen, first of all, I would like to thank everyone who has worked on this report, that is to say, all collaborators, but also the people from the Committee on Women\' s Rights and Equal Opportunities and the interpreters, who have worked very hard. This report is also a reaction to the excellent communication by the Committee on new measures to fight trafficking in women. By way of preparing for the report, the Committee on Women\' s Rights and Equal Opportunities organised a public hearing which involved experts and the presence of a victim who came to give her story. A delegation of this committee, together with Mrs Diamantopoulou, visited a shelter for victims of trafficking in people. Moreover, the Ministries of Foreign Affairs of Member States and candidate countries received a questionnaire on how they tackle trafficking in women, the results of which will be made available to the European Commission.\n<P>\nThe report primarily aims to fight trafficking in women, but also in children and men, that is to say in people in general. Trafficking in children does exist, but they are used as adults. Men, too, are victims of trafficking in people and are sexually abused. In fact, the sex industry is not the only market on which the victims of such trafficking are sold. In Belgium, 40 percent of the victims end up on the labour market, in the textile, hotel and catering and fruit-picking industries, bakeries and the construction industry, or as house staff or au-pair girls, obliged to work as slaves in degrading conditions. Victims are also recruited for the marriage market, as well as to sports clubs and football clubs. According to estimates by the United Nations and the International Organisation for Migration, the IOM, every year four million people throughout the world fall victim to trafficking, 500 000 of whom end up in Europe. All the signs are there that the number of victims is rising and that the influx from Central and Eastern European countries has exceeded the existing stream from Africa, Latin America, the Caribbean and Asia.\n<P>\nIn a report by the United Nations, it is stressed that trafficking in people is one of the fastest growing forms of organised crime. The huge profits and relative safety for the perpetrators who generate this type of crime will undoubtedly have something to do with this. The penalties for smuggling narcotics, for example, are far higher than those for trafficking in women. Victims are often unable to speak out on account of the illegal situation they are in. Since there are clear indications that these problems are developing within the framework of international networks, it is important that these problems are addressed and tackled at European level. In order to tackle trafficking in people adequately, we first of all need a clear definition of trafficking in people. Priority must also be given to the fight against organised networks which are not only involved in trafficking in people but which are also involved in all kinds of other criminal activity, such as the trade in narcotics, arms and such like. I therefore applaud the new Community initiatives concerning money laundering where the income from trafficking in women plays a major role. Various initiatives have already been taken at European level. Efforts to increase public awareness have got off to a good start in the form of activities on the part of Interpol and Europol, initiatives in every individual Member State, Habitat projects, etc. However, the harmonisation of the different national legislations in this field and the ensuing discrepancies in methods of investigation and prosecution have to be tackled at European level as a matter of priority. From a survey organised in connection with this report, it is quite clear that there are considerable discrepancies in this sphere between the Member States and between one candidate coun ...

# %%
results
# Out:
#                                           contribution chapter  \
# 1    KER ID=1 LANGUAGE="IT" NAME="Buttiglione">\nMa...       0
# 2    KER ID=2 LANGUAGE="IT" NAME="Tajani">\nMadam P...       0
# 3    KER ID=3 LANGUAGE="IT" NAME="Napoletano">\nMad...       0
# 4    KER ID=4 NAME="President">\nThank you, Mrs Nap...       0
# 6    KER ID=5 NAME="President">\nI have two stateme...       1
# ..                                                 ...     ...
# 276  KER ID=262 LANGUAGE="DE" NAME="Berger">\nMr Pr...      14
# 277  KER ID=263 LANGUAGE="SV" NAME="Thors">\nMr Pre...      14
# 278  KER ID=264 NAME="Berthu">\nMr President, the K...      14
# 279  KER ID=265 NAME="Vitorino">\nMr President, the...      14
# 280  KER ID=266 NAME="President">\nThat concludes t...      14
#
#                               chapter_title     contribution_id speaker_name  \
# 1                                              year-month-day-1  Buttiglione
# 2                                              year-month-day-2       Tajani
# 3                                              year-month-day-3   Napoletano
# 4                                              year-month-day-4    President
# 6               Statements by the President    year-month-day-5    President
# ..                                      ...                 ...          ...
# 276  Readmission of third country nationals  year-month-day-262       Berger
# 277  Readmission of third country nationals  year-month-day-263        Thors
# 278  Readmission of third country nationals  year-month-day-264       Berthu
# 279  Readmission of third country nationals  year-month-day-265     Vitorino
# 280  Readmission of third country nationals  year-month-day-266    President
#
#     language                                  contribution_text
# 1         IT  Madam President, I requested the floor in orde...
# 2         IT  Madam President, I wholeheartedly support Mr B...
# 3         IT  Madam President, we know President Kuçan and w...
# 4             Thank you, Mrs Napoletano. I propose to the th...
# 6             I have two statements to make. You should alre...
# ..       ...                                                ...
# 276       DE  Mr President, I would first like to thank the ...
# 277       SV  Mr President, Commissioner, I want to say that...
# 278           Mr President, the Karamanou report asks the Eu...
# 279           Mr President, the Commission would like to con...
# 280           That concludes the debate. The vote will be ta...
#
# [266 rows x 7 columns]
