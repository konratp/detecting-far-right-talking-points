# %% [markdown]
# # Loading Data

# %%
import pandas as pd
import nltk
import os
import re
import string

# %%
#sample dataframe
data = {
    "speaker_id": [2],
    "name": ["Evans, Robert J"],
    "language": ["en"],
    "party_affiliation": ["unknown"],
    "paragraph_text": ["Madam President, on a point of order. You will be aware from the press and television that there have been a number of bomb explosions and killings in Sri Lanka. One of the people assassinated very recently in Sri Lanka was Mr Kumar Ponnambalam, who had visited the European Parliament just a few months ago. Would it be appropriate for you, Madam President, to write a letter to the Sri Lankan President expressing Parliament's regret at his and the other violent deaths in Sri Lanka and urging her to do everything she possibly can to seek a peaceful reconciliation to a very difficult situation?"],
    "date": ["00-01-17"],
    "right_wing": [0]
}

df = pd.DataFrame(data)
df.head()
# Out:
#    speaker_id             name language party_affiliation  \
# 0           2  Evans, Robert J       en           unknown
#
#                                       paragraph_text      date  right_wing
# 0  Madam President, on a point of order. You will...  00-01-17           0

# %%
path = f"{os.getcwd()}/data_sample"

# %%
corpus = {}
for i in os.listdir(path):
    corpus[i] = nltk.data.load(f'{path}/{i}', format='raw')

# %%
corpus2 = pd.DataFrame.from_dict([corpus]).T

# %%
for index, i in enumerate(corpus2[0]):
    corpus2.iloc[index][0] = i.decode('UTF-8')

# %%
corpus2
# Out:
#                                                                  0
# ep-00-06-13.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-01-18.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-14.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-01-19.txt  <CHAPTER ID=5>\nMiddle East peace process (con...
# ep-00-06-14.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Presiden...
# ep-00-01-21.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-11.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-03-30.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-10.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-06-15.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="NL" ...
# ep-00-04-12.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-13.txt  <CHAPTER ID=1>\nPrinciples for recording taxes...
# ep-00-06-16.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Helmer">...
# ep-00-02-15.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-09-08.txt  <CHAPTER ID=1>\nTribute\n<SPEAKER ID=1 NAME="P...
# ep-00-09-20.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-21.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="ES" ...
# ep-00-02-14.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-02-16.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-02-02.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-10-02.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-10-03.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Presiden...
# ep-00-02-03.txt  <CHAPTER ID=1>\nEnd-of-life vehicles\n<SPEAKER...
# ep-00-02-17.txt  <CHAPTER ID=1>\nResumption of the sitting\n<SP...
# ep-00-05-19.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-05-18.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="IT" ...
# ep-00-05-15.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-07-04.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-07-05.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-05-16.txt  <CHAPTER ID=1>\nDecision on urgent procedure\n...
# ep-00-07-07.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-07-06.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-05-17.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-05-03.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-07.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="DE" ...
# ep-00-07-03.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-06.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="EL" ...
# ep-00-05-04.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-09-04.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-05.txt  <CHAPTER ID=1>\nWelcome\n<SPEAKER ID=1 NAME="P...
# ep-00-02-18.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-03-17.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-03-02.txt  <CHAPTER ID=2>\nShipwreck of the Erika\n<SPEAK...
# ep-00-03-16.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Presiden...
# ep-00-03-14.txt  <CHAPTER ID=1>\nOpening of the session\n<SPEAK...
# ep-00-03-29.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-03-15.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="NL" ...
# ep-00-03-01.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-01-17.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-03-13.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...

# %%
#text = corpus2[0][7]
text = corpus2[0][10]

# %%
#text

# %%
chap_split = text.split("<CHAP")

# %%
chap_split = [i for i in chap_split if i != '']
#chap_split

# %%
len(chap_split)
# Out:
# 12

# %%
spea_split = []
for i in chap_split:
    spea_split.append(i.split("SPEA"))

# %%
#spea_split

# %%
j = 0
for i in spea_split:
    print(len(i))
    j += len(i)
# Out:
# 15
# 47
# 48
# 29
# 14
# 15
# 68
# 4
# 37
# 12
# 16
# 11

# %%
j
# Out:
# 316

# %%
test_corp = pd.DataFrame(spea_split).T
test_corp
# Out:
#                                                    0   \
# 0   TER ID=1>\nAdoption of the Minutes of the prev...
# 1   KER ID=1 NAME="President">\nThe Minutes of yes...
# 2   KER ID=2 NAME="Ludford">\nMadam President, I s...
# 3   KER ID=3 NAME="President">\nThank you, Mrs Lud...
# 4   KER ID=4 NAME="Corbett">\nMadam President, ite...
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
#                                                    1   \
# 0                                   TER ID=2>\nIGC\n<
# 1   KER ID=15 NAME="President">\nThe next item is ...
# 2   KER ID=16 NAME="Ribeiro e Castro">\nMadam Pres...
# 3   KER ID=17 NAME="President">\nThank you, Mr Rib...
# 4   KER ID=18 LANGUAGE="FR" NAME="Berthu">\nMadam ...
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
#                                                    2   \
# 0                                  TER ID=3>\nVOTE\n<
# 1   KER ID=61 NAME=" on the additionality principl...
# 2   KER ID=62 LANGUAGE="DE" NAME="Liese">\nMr Pres...
# 3   KER ID=63 NAME="President">\nThank you, Mr Lie...
# 4   KER ID=64 NAME="Wallström">\nIt is that very c...
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
#                                                    3   \
# 0                    TER ID=4>\nIGC (continuation)\n<
# 1   KER ID=108 NAME="President">\nThe next item is...
# 2   KER ID=109 LANGUAGE="IT" NAME="Segni">\nMadam ...
# 3   KER ID=110 LANGUAGE="ES" NAME="Garriga Polledo...
# 4   KER ID=111 LANGUAGE="IT" NAME="Imbeni">\nMadam...
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
#                                                    4   \
# 0                    TER ID=5>\nFamine in Ethiopia\n<
# 1   KER ID=136 NAME="President">\nThe next item is...
# 2   KER ID=137 NAME="Seixas da Costa">\n Madam Pre...
# 3   KER ID=138 NAME="Patten">\nI am grateful for t...
# 4   KER ID=139 NAME="Corrie">\nMadam President, I ...
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
#                                                    5   \
# 0   TER ID=6>\nStabilisation and association proce...
# 1   KER ID=149 NAME="President">\nThe next item is...
# 2   KER ID=150 LANGUAGE="NL" NAME="Lagendijk">\nMr...
# 3   KER ID=151 NAME="Seixas da Costa">\n. (PT) Mr ...
# 4   KER ID=152 LANGUAGE="DE" NAME="Pack">\nMr Pres...
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
#                                                    6   \
# 0               TER ID=7>\nQuestion Time (Council)\n<
# 1   KER ID=163 NAME="President">\nThe next item is...
# 2   KER ID=164 NAME="Efstratios Korakas">\nQuestio...
# 3   KER ID=165 NAME="Emmanouil Bakopoulos">\nQuest...
# 4   KER ID=166 NAME="Ioannis Theonas">\nQuestion N...
# ..                                                ...
# 63  KER ID=225 NAME="Mihail Papayannakis, which ha...
# 64  KER ID=226 NAME="Seixas da Costa">\nMr Papayan...
# 65  KER ID=227 LANGUAGE="SV" NAME="Sjöstedt">\nMy ...
# 66  KER ID=228 NAME="Seixas da Costa">\nMr Sjösted...
# 67  KER ID=229 NAME="President">\nThank you very m...
#
#                                                    7   \
# 0   TER ID=9>\nAddress by Mr Klestil, President of...
# 1   KER ID=230 NAME="President">\nMr President, yo...
# 2   KER ID=231 LANGUAGE="DE" NAME="Klestil">\nBefo...
# 3   KER ID=232 NAME="President">\nMr President, we...
# 4                                                None
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
#                                                    8   \
# 0   TER ID=10>\nFinancial services and complementa...
# 1   KER ID=233 NAME="President">\nThe next item is...
# 2   KER ID=234 LANGUAGE="ES" NAME="García-Margallo...
# 3   KER ID=235 LANGUAGE="DE" NAME="Kuckelkorn">\n ...
# 4   KER ID=236 LANGUAGE="ES" NAME="Medina Ortega">...
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
#                                                    9   \
# 0   TER ID=11>\nStrategy for Europe' s Internal Ma...
# 1   KER ID=269 NAME="President">\nThe next item is...
# 2   KER ID=270 LANGUAGE="ES" NAME="Palacio Vallele...
# 3   KER ID=271 LANGUAGE="ES" NAME="Berenguer Fuste...
# 4   KER ID=272 LANGUAGE="ES" NAME="Medina Ortega">...
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
#                                                    10  \
# 0     TER ID=12>\n2001: European Year of Languages\n<
# 1   KER ID=280 NAME="President">\nThe next item is...
# 2   KER ID=281 LANGUAGE="PT" NAME="Graça Moura">\n...
# 3   KER ID=282 LANGUAGE="DE" NAME="Pack">\nMr Pres...
# 4   KER ID=283 LANGUAGE="DE" NAME="Prets">\nMr Pre...
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
#                                                    11
# 0                                TER ID=13>\nYouth\n<
# 1   KER ID=295 NAME="President">\nThe next item is...
# 2   KER ID=296 LANGUAGE="DE" NAME="Gröner">\nMr Pr...
# 3   KER ID=297 LANGUAGE="DE" NAME="Zissener">\nMr ...
# 4   KER ID=298 NAME="Evans, Robert">\nMr President...
# ..                                                ...
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
# [68 rows x 12 columns]

# %%
d = {}
counter = 0
for text in spea_split:
    d[counter] = []
    for contribution in text:
        d[counter].append(contribution)
    counter += 1

# %%
spea_split[2][0].partition('ID=')[2].partition('>\n')[0]
# Out:
# '3'

# %%
d = {}

for chapter in spea_split:
    #careful: we assume that the chapter title is contained in the first element of the list 'chapter'
    d[chapter[0].partition('ID=')[2].partition('>\n')[0]] = []
    for contribution in chapter:
        d[chapter[0].partition('ID=')[2].partition('>\n')[0]].append(contribution)

# %%
entries = []
chapter = []
for i in d:
    entries.extend(d[i])
    for k in range(len(d[i])):
        chapter.append(i)

# %%
titles = []
for i in d:
    titles.append(d[i][0])

# %%
results = pd.DataFrame({'contribution': entries,'chapter': chapter})
results
# Out:
#                                           contribution chapter
# 0    TER ID=1>\nAdoption of the Minutes of the prev...       1
# 1    KER ID=1 NAME="President">\nThe Minutes of yes...       1
# 2    KER ID=2 NAME="Ludford">\nMadam President, I s...       1
# 3    KER ID=3 NAME="President">\nThank you, Mrs Lud...       1
# 4    KER ID=4 NAME="Corbett">\nMadam President, ite...       1
# ..                                                 ...     ...
# 311  KER ID=300 NAME="Wyn">\nMr President, I also c...      13
# 312  KER ID=301 LANGUAGE="DE" NAME="Pack">\nMr Pres...      13
# 313  KER ID=302 LANGUAGE="DE" NAME="Karas">\nMr Pre...      13
# 314  KER ID=303 LANGUAGE="FR" NAME="Reding">\nMr Pr...      13
# 315  KER ID=304 NAME="President">\nThank you very m...      13
#
# [316 rows x 2 columns]

# %%
chap_titles = {}
for i in results.contribution:
    if 'TER ID=' in i:
        chap_titles[i.partition('ID=')[2].partition('>\n')[0]] = i.partition('>\n')[2].partition('\n<')[0]

# %%
chap_titles
# Out:
# {'1': 'Adoption of the Minutes of the previous sitting',
#  '2': 'IGC',
#  '3': 'VOTE',
#  '4': 'IGC (continuation)',
#  '5': 'Famine in Ethiopia',
#  '6': 'Stabilisation and association process for countries of South-Eastern Europe',
#  '7': 'Question Time (Council)',
#  '9': 'Address by Mr Klestil, President of the Republic of Austria',
#  '10': 'Financial services and complementary pensions',
#  '11': "Strategy for Europe' s Internal Market",
#  '12': '2001: European Year of Languages',
#  '13': 'Youth'}

# %%
#results['chapter'] = results['chapter'] -1
results['chapter'] = results['chapter'].astype(str)

results['chapter_title'] = results['chapter'].map(chap_titles)

# %%
results
# Out:
#                                           contribution chapter  \
# 0    TER ID=1>\nAdoption of the Minutes of the prev...       1
# 1    KER ID=1 NAME="President">\nThe Minutes of yes...       1
# 2    KER ID=2 NAME="Ludford">\nMadam President, I s...       1
# 3    KER ID=3 NAME="President">\nThank you, Mrs Lud...       1
# 4    KER ID=4 NAME="Corbett">\nMadam President, ite...       1
# ..                                                 ...     ...
# 311  KER ID=300 NAME="Wyn">\nMr President, I also c...      13
# 312  KER ID=301 LANGUAGE="DE" NAME="Pack">\nMr Pres...      13
# 313  KER ID=302 LANGUAGE="DE" NAME="Karas">\nMr Pre...      13
# 314  KER ID=303 LANGUAGE="FR" NAME="Reding">\nMr Pr...      13
# 315  KER ID=304 NAME="President">\nThank you very m...      13
#
#                                        chapter_title
# 0    Adoption of the Minutes of the previous sitting
# 1    Adoption of the Minutes of the previous sitting
# 2    Adoption of the Minutes of the previous sitting
# 3    Adoption of the Minutes of the previous sitting
# 4    Adoption of the Minutes of the previous sitting
# ..                                               ...
# 311                                            Youth
# 312                                            Youth
# 313                                            Youth
# 314                                            Youth
# 315                                            Youth
#
# [316 rows x 3 columns]

# %% [markdown]
# hello
