# %% [markdown]
# # Loading Data

# %%
import pandas as pd
import numpy as np
import nltk
import os
import re
import string

# %%
#sample dataframe
data = {
    "speaker_id": [2],
    "name": ["Evans, Robert J"],
    "language": ["en"],
    "party_affiliation": ["unknown"],
    "paragraph_text": ["Madam President, on a point of order. You will be aware from the press and television that there have been a number of bomb explosions and killings in Sri Lanka. One of the people assassinated very recently in Sri Lanka was Mr Kumar Ponnambalam, who had visited the European Parliament just a few months ago. Would it be appropriate for you, Madam President, to write a letter to the Sri Lankan President expressing Parliament's regret at his and the other violent deaths in Sri Lanka and urging her to do everything she possibly can to seek a peaceful reconciliation to a very difficult situation?"],
    "date": ["00-01-17"],
    "right_wing": [0]
}

df = pd.DataFrame(data)
df.head()
# Out:
#    speaker_id             name language party_affiliation  \
# 0           2  Evans, Robert J       en           unknown
#
#                                       paragraph_text      date  right_wing
# 0  Madam President, on a point of order. You will...  00-01-17           0

# %%
path = f"{os.getcwd()}/data_sample"

# %%
corpus = {}
for i in os.listdir(path):
    corpus[i] = nltk.data.load(f'{path}/{i}', format='raw')

# %%
corpus2 = pd.DataFrame.from_dict([corpus]).T

# %%
for index, i in enumerate(corpus2[0]):
    corpus2.iloc[index][0] = i.decode('UTF-8')

# %%
corpus2
# Out:
#                                                                  0
# ep-00-06-13.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-01-18.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-14.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-01-19.txt  <CHAPTER ID=5>\nMiddle East peace process (con...
# ep-00-06-14.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Presiden...
# ep-00-01-21.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-11.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-03-30.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-10.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-06-15.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="NL" ...
# ep-00-04-12.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-04-13.txt  <CHAPTER ID=1>\nPrinciples for recording taxes...
# ep-00-06-16.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Helmer">...
# ep-00-02-15.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-09-08.txt  <CHAPTER ID=1>\nTribute\n<SPEAKER ID=1 NAME="P...
# ep-00-09-20.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-21.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="ES" ...
# ep-00-02-14.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-02-16.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-02-02.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-10-02.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-10-03.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Presiden...
# ep-00-02-03.txt  <CHAPTER ID=1>\nEnd-of-life vehicles\n<SPEAKER...
# ep-00-02-17.txt  <CHAPTER ID=1>\nResumption of the sitting\n<SP...
# ep-00-05-19.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-05-18.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="IT" ...
# ep-00-05-15.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-07-04.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-07-05.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-05-16.txt  <CHAPTER ID=1>\nDecision on urgent procedure\n...
# ep-00-07-07.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-07-06.txt  <CHAPTER ID=1>\nApproval of the Minutes of the...
# ep-00-05-17.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-05-03.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-07.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="DE" ...
# ep-00-07-03.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-06.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="EL" ...
# ep-00-05-04.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-09-04.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-09-05.txt  <CHAPTER ID=1>\nWelcome\n<SPEAKER ID=1 NAME="P...
# ep-00-02-18.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-03-17.txt  <CHAPTER ID=1>\nAdoption of the Minutes of the...
# ep-00-03-02.txt  <CHAPTER ID=2>\nShipwreck of the Erika\n<SPEAK...
# ep-00-03-16.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 NAME="Presiden...
# ep-00-03-14.txt  <CHAPTER ID=1>\nOpening of the session\n<SPEAK...
# ep-00-03-29.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-03-15.txt  <CHAPTER ID=0>\n\n<SPEAKER ID=1 LANGUAGE="NL" ...
# ep-00-03-01.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-01-17.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...
# ep-00-03-13.txt  <CHAPTER ID=1>\nResumption of the session\n<SP...

# %%
#text = corpus2[0][7]
text = corpus2[0][18]

# %%
#text

# %%
chap_split = text.split("<CHAP")

# %%
chap_split = [i for i in chap_split if i != '']
#chap_split

# %%
len(chap_split)
# Out:
# 16

# %%
spea_split = []
for i in chap_split:
    spea_split.append(i.split("SPEA"))

# %%
#spea_split

# %%
j = 0
for i in spea_split:
    print(len(i))
    j += len(i)
# Out:
# 8
# 29
# 5
# 2
# 7
# 3
# 38
# 19
# 28
# 73
# 4
# 15
# 20
# 7
# 7
# 10

# %%
j
# Out:
# 275

# %%
test_corp = pd.DataFrame(spea_split).T
test_corp
# Out:
#                                                    0   \
# 0   TER ID=1>\nAdoption of the Minutes of the prev...
# 1   KER ID=1 NAME="President">\nThe Minutes of yes...
# 2   KER ID=2 NAME="Stevenson">\nMr President, I se...
# 3   KER ID=3 LANGUAGE="NL" NAME="Peijs">\nMr Presi...
# 4   KER ID=4 LANGUAGE="DE" NAME="Swoboda">\nMr Pre...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    1   \
# 0   TER ID=2>\nCoherence of EU policies with devel...
# 1   KER ID=8 NAME="President">\nThe next item is t...
# 2   KER ID=9 LANGUAGE="PT" NAME="Amado">\nMr Presi...
# 3   KER ID=10 NAME="Nielson">\n. Let me start by s...
# 4   KER ID=11 LANGUAGE="NL" NAME="Maij-Weggen">\nM...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    2   \
# 0   TER ID=3>\nNext session of UN Human Rights Com...
# 1   KER ID=36 NAME="President">\nThe next item is ...
# 2   KER ID=37 LANGUAGE="PT" NAME="Amado">\nMr Pres...
# 3   KER ID=38 NAME="Patten">\n. Mr President, I wo...
# 4   KER ID=39 NAME="President">\nThank you very mu...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    3   \
# 0                               TER ID=4>\nWelcome\n<
# 1   KER ID=40 NAME="President">\nI am delighted to...
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    4   \
# 0                                  TER ID=5>\nVOTE\n<
# 1   KER ID=41 NAME="Nielson">\n. As Mrs Wallström ...
# 2   KER ID=42 LANGUAGE="DE" NAME="Graefe zu Baring...
# 3   KER ID=43 NAME="Byrne">\n. I regret to say tha...
# 4   KER ID=44 LANGUAGE="DE" NAME="Graefe zu Baring...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    5   \
# 0                               TER ID=6>\nWelcome\n<
# 1   KER ID=47 NAME="President">\nThis is perhaps a...
# 2   KER ID=48 LANGUAGE="FR" NAME="Wurtz">\nMr Pres...
# 3                                                None
# 4                                                None
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    6   \
# 0                   TER ID=7>\nVOTE (continuation)\n<
# 1   KER ID=49 NAME="President">\nWe shall now cont...
# 2   KER ID=50 NAME="Nielson">\n. As regards the Co...
# 3   KER ID=51 LANGUAGE="FR" NAME="Caudron">\n. (FR...
# 4   KER ID=52 LANGUAGE="FR" NAME="Caudron">\n. (FR...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    7   \
# 0   TER ID=8>\nNext session of UN Human Rights Com...
# 1   KER ID=86 NAME="President">\nThe next item is ...
# 2   KER ID=87 LANGUAGE="ES" NAME="Salafranca Sánch...
# 3   KER ID=88 LANGUAGE="IT" NAME="Fava">\nMr Presi...
# 4   KER ID=89 LANGUAGE="SV" NAME="Malmström">\nMr ...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    8   \
# 0                      TER ID=9>\nCyprus and Malta\n<
# 1   KER ID=104 NAME="President">\nThe next item is...
# 2   KER ID=105 LANGUAGE="PT" NAME="Seixas da Costa...
# 3   KER ID=106 LANGUAGE="DE" NAME="Verheugen">\nMr...
# 4   KER ID=107 LANGUAGE="DE" NAME="Brok">\n. (DE) ...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    9   \
# 0              TER ID=10>\nQuestion Time (Council)\n<
# 1   KER ID=131 NAME="President">\nThe next item is...
# 2   KER ID=132 NAME="Manuel Medina Ortega">\nQuest...
# 3   KER ID=133 LANGUAGE="PT" NAME="Seixas da Costa...
# 4   KER ID=134 LANGUAGE="ES" NAME="Medina Ortega">...
# ..                                                ...
# 68  KER ID=198 LANGUAGE="PT" NAME="Seixas da Costa...
# 69  KER ID=199 LANGUAGE="SV" NAME="Andersson">\nMr...
# 70  KER ID=200 NAME="President">\nMr President-in-...
# 71  KER ID=201 LANGUAGE="PT" NAME="Seixas da Costa...
# 72  KER ID=202 NAME="President">\nSince the time a...
#
#                                                    10  \
# 0   TER ID=12>\nAddress by Mr Vaclav Havel, Presid...
# 1   KER ID=203 NAME="President">\nMr President in ...
# 2   KER ID=204 NAME="Vaclav Havel">\nMadam Preside...
# 3   KER ID=205 NAME="President">\nMr President, al...
# 4                                                None
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    11  \
# 0                TER ID=13>\nACP-EU Joint Assembly\n<
# 1   KER ID=206 NAME="President">\nThe next item is...
# 2   KER ID=207 NAME="Corrie">\n, rapporteur.- Mr P...
# 3   KER ID=208 LANGUAGE="DE" NAME="Zimmerling">\nM...
# 4   KER ID=209 NAME="President">\nThank you, Mr Zi...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    12  \
# 0   TER ID=14>\nStabilisation and association agre...
# 1   KER ID=220 NAME="President">\nThe next item is...
# 2   KER ID=221 LANGUAGE="DE" NAME="Swoboda">\nMr P...
# 3   KER ID=222 LANGUAGE="NL" NAME="Oostlander">\nM...
# 4   KER ID=223 LANGUAGE="IT" NAME="Lavarra">\nMr P...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    13  \
# 0              TER ID=15>\nAgreement on comitology\n<
# 1   KER ID=239 NAME="President">\nThe next item is...
# 2   KER ID=240 LANGUAGE="IT" NAME="Frassoni">\n. (...
# 3   KER ID=241 LANGUAGE="DE" NAME="Schleicher">\nM...
# 4   KER ID=242 NAME="Corbett">\nMr President, I co...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    14  \
# 0   TER ID=16>\nProtocol on the excessive deficit ...
# 1   KER ID=245 NAME="President">\nThe next item is...
# 2   KER ID=246 LANGUAGE="ES" NAME="Knörr Borràs">\...
# 3   KER ID=247 LANGUAGE="DE" NAME="Karas">\nMr Pre...
# 4   KER ID=248 LANGUAGE="NL" NAME="Maaten">\nMr Pr...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
#                                                    15
# 0   TER ID=17>\nIncreasing penal sanctions against...
# 1   KER ID=251 NAME="President">\nThe next item is...
# 2   KER ID=252 LANGUAGE="SV" NAME="Cederschiöld">\...
# 3   KER ID=253 LANGUAGE="PT" NAME="Coelho">\nMr Pr...
# 4   KER ID=254 LANGUAGE="DE" NAME="Schulz">\nMr Pr...
# ..                                                ...
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
#
# [73 rows x 16 columns]

# %%
d = {}
counter = 0
for text in spea_split:
    d[counter] = []
    for contribution in text:
        d[counter].append(contribution)
    counter += 1

# %%
spea_split[2][0].partition('ID=')[2].partition('>\n')[0]
# Out:
# '3'

# %%
d = {}

for chapter in spea_split:
    #careful: we assume that the chapter title is contained in the first element of the list 'chapter'
    d[chapter[0].partition('ID=')[2].partition('>\n')[0]] = []
    for contribution in chapter:
        d[chapter[0].partition('ID=')[2].partition('>\n')[0]].append(contribution)
        
def konrat(x):
    return x.partition('LANGUAGE=\"')[2].partition('\"')[0]

# %%
entries = []
chapter = []
for i in d:
    entries.extend(d[i])
    for k in range(len(d[i])):
        chapter.append(i)

# %%
titles = []
for i in d:
    titles.append(d[i][0])

# %%
results = pd.DataFrame({'contribution': entries,'chapter': chapter})
results
# Out:
#                                           contribution chapter
# 0    TER ID=1>\nAdoption of the Minutes of the prev...       1
# 1    KER ID=1 NAME="President">\nThe Minutes of yes...       1
# 2    KER ID=2 NAME="Stevenson">\nMr President, I se...       1
# 3    KER ID=3 LANGUAGE="NL" NAME="Peijs">\nMr Presi...       1
# 4    KER ID=4 LANGUAGE="DE" NAME="Swoboda">\nMr Pre...       1
# ..                                                 ...     ...
# 270  KER ID=255 LANGUAGE="FR" NAME="Berthu">\nMr Pr...      17
# 271  KER ID=256 LANGUAGE="DA" NAME="Krarup">\nI sho...      17
# 272  KER ID=257 LANGUAGE="DE" NAME="Karas">\nMr Pre...      17
# 273  KER ID=258 LANGUAGE="DE" NAME="Schreyer">\nMr ...      17
# 274  KER ID=259 NAME="President">\nThank you very m...      17
#
# [275 rows x 2 columns]

# %%
chap_titles = {}
for i in results.contribution:
    if 'TER ID=' in i:
        chap_titles[i.partition('ID=')[2].partition('>\n')[0]] = i.partition('>\n')[2].partition('\n<')[0]

# %%
chap_titles
# Out:
# {'1': 'Adoption of the Minutes of the previous sitting',
#  '2': 'Coherence of EU policies with development',
#  '3': 'Next session of UN Human Rights Commission',
#  '4': 'Welcome',
#  '5': 'VOTE',
#  '6': 'Welcome',
#  '7': 'VOTE (continuation)',
#  '8': 'Next session of UN Human Rights Commission (continuation)',
#  '9': 'Cyprus and Malta',
#  '10': 'Question Time (Council)',
#  '12': 'Address by Mr Vaclav Havel, President of the Czech Republic',
#  '13': 'ACP-EU Joint Assembly',
#  '14': 'Stabilisation and association agreement with FYROM',
#  '15': 'Agreement on comitology',
#  '16': 'Protocol on the excessive deficit procedure',
#  '17': 'Increasing penal sanctions against counterfeiting of the euro'}

# %%
results['chapter'] = results['chapter'].astype(str)

results['chapter_title'] = results['chapter'].map(chap_titles)

# %%
results = results.reset_index(drop = True)

# %% [markdown]
# hello

# %%
len(results.chapter.unique())
# Out:
# 16

# %%
results = results[results.contribution.str.contains('KER ID')]

# %%
sp_id = {}
for i in results.contribution:
    sp_id[i.partition('KER ID=')[2].partition(' ')[0]] = i.partition('NAME=\"')[2].partition('\">')[0]

# %%
results['contribution_id'] = sp_id.keys()
results
# Out:
#                                           contribution chapter  \
# 0    KER ID=1 NAME="President">\nThe Minutes of yes...       1
# 1    KER ID=2 NAME="Stevenson">\nMr President, I se...       1
# 2    KER ID=3 LANGUAGE="NL" NAME="Peijs">\nMr Presi...       1
# 3    KER ID=4 LANGUAGE="DE" NAME="Swoboda">\nMr Pre...       1
# 4    KER ID=5 NAME="President">\nMr Swoboda, I can ...       1
# ..                                                 ...     ...
# 254  KER ID=255 LANGUAGE="FR" NAME="Berthu">\nMr Pr...      17
# 255  KER ID=256 LANGUAGE="DA" NAME="Krarup">\nI sho...      17
# 256  KER ID=257 LANGUAGE="DE" NAME="Karas">\nMr Pre...      17
# 257  KER ID=258 LANGUAGE="DE" NAME="Schreyer">\nMr ...      17
# 258  KER ID=259 NAME="President">\nThank you very m...      17
#
#                                          chapter_title contribution_id
# 0      Adoption of the Minutes of the previous sitting               1
# 1      Adoption of the Minutes of the previous sitting               2
# 2      Adoption of the Minutes of the previous sitting               3
# 3      Adoption of the Minutes of the previous sitting               4
# 4      Adoption of the Minutes of the previous sitting               5
# ..                                                 ...             ...
# 254  Increasing penal sanctions against counterfeit...             255
# 255  Increasing penal sanctions against counterfeit...             256
# 256  Increasing penal sanctions against counterfeit...             257
# 257  Increasing penal sanctions against counterfeit...             258
# 258  Increasing penal sanctions against counterfeit...             259
#
# [259 rows x 4 columns]

# %%
results['speaker_name'] = results['contribution_id'].map(sp_id)
results
# Out:
#                                           contribution chapter  \
# 0    KER ID=1 NAME="President">\nThe Minutes of yes...       1
# 1    KER ID=2 NAME="Stevenson">\nMr President, I se...       1
# 2    KER ID=3 LANGUAGE="NL" NAME="Peijs">\nMr Presi...       1
# 3    KER ID=4 LANGUAGE="DE" NAME="Swoboda">\nMr Pre...       1
# 4    KER ID=5 NAME="President">\nMr Swoboda, I can ...       1
# ..                                                 ...     ...
# 254  KER ID=255 LANGUAGE="FR" NAME="Berthu">\nMr Pr...      17
# 255  KER ID=256 LANGUAGE="DA" NAME="Krarup">\nI sho...      17
# 256  KER ID=257 LANGUAGE="DE" NAME="Karas">\nMr Pre...      17
# 257  KER ID=258 LANGUAGE="DE" NAME="Schreyer">\nMr ...      17
# 258  KER ID=259 NAME="President">\nThank you very m...      17
#
#                                          chapter_title contribution_id  \
# 0      Adoption of the Minutes of the previous sitting               1
# 1      Adoption of the Minutes of the previous sitting               2
# 2      Adoption of the Minutes of the previous sitting               3
# 3      Adoption of the Minutes of the previous sitting               4
# 4      Adoption of the Minutes of the previous sitting               5
# ..                                                 ...             ...
# 254  Increasing penal sanctions against counterfeit...             255
# 255  Increasing penal sanctions against counterfeit...             256
# 256  Increasing penal sanctions against counterfeit...             257
# 257  Increasing penal sanctions against counterfeit...             258
# 258  Increasing penal sanctions against counterfeit...             259
#
#     speaker_name
# 0      President
# 1      Stevenson
# 2          Peijs
# 3        Swoboda
# 4      President
# ..           ...
# 254       Berthu
# 255       Krarup
# 256        Karas
# 257     Schreyer
# 258    President
#
# [259 rows x 5 columns]

# %%
for i in results.contribution:
    results['language'][i] = i.partition('LANGUAGE=\"')[2].partition('\"')[0]

# %%
def konrat(x):
    return x.partition('LANGUAGE=\"')[2].partition('\"')[0]

# %%
results.iloc[1].contribution.partition('LANGUAGE=\"')[2].partition('\"')[0]
# Out:
# ''

# %%
results['language'] = results['contribution'].apply(konrat)

# %%
results
# Out:
#                                           contribution chapter  \
# 0    KER ID=1 NAME="President">\nThe Minutes of yes...       1
# 1    KER ID=2 NAME="Stevenson">\nMr President, I se...       1
# 2    KER ID=3 LANGUAGE="NL" NAME="Peijs">\nMr Presi...       1
# 3    KER ID=4 LANGUAGE="DE" NAME="Swoboda">\nMr Pre...       1
# 4    KER ID=5 NAME="President">\nMr Swoboda, I can ...       1
# ..                                                 ...     ...
# 254  KER ID=255 LANGUAGE="FR" NAME="Berthu">\nMr Pr...      17
# 255  KER ID=256 LANGUAGE="DA" NAME="Krarup">\nI sho...      17
# 256  KER ID=257 LANGUAGE="DE" NAME="Karas">\nMr Pre...      17
# 257  KER ID=258 LANGUAGE="DE" NAME="Schreyer">\nMr ...      17
# 258  KER ID=259 NAME="President">\nThank you very m...      17
#
#                                          chapter_title contribution_id  \
# 0      Adoption of the Minutes of the previous sitting               1
# 1      Adoption of the Minutes of the previous sitting               2
# 2      Adoption of the Minutes of the previous sitting               3
# 3      Adoption of the Minutes of the previous sitting               4
# 4      Adoption of the Minutes of the previous sitting               5
# ..                                                 ...             ...
# 254  Increasing penal sanctions against counterfeit...             255
# 255  Increasing penal sanctions against counterfeit...             256
# 256  Increasing penal sanctions against counterfeit...             257
# 257  Increasing penal sanctions against counterfeit...             258
# 258  Increasing penal sanctions against counterfeit...             259
#
#     speaker_name language
# 0      President
# 1      Stevenson
# 2          Peijs       NL
# 3        Swoboda       DE
# 4      President
# ..           ...      ...
# 254       Berthu       FR
# 255       Krarup       DA
# 256        Karas       DE
# 257     Schreyer       DE
# 258    President
#
# [259 rows x 6 columns]

# %%
def konrat2(x):
    return 'year-month-day-'+x

# %%
results['contribution_id'] = results['contribution_id'].apply(konrat2)

# %%
results
# Out:
#                                           contribution chapter  \
# 0    KER ID=1 NAME="President">\nThe Minutes of yes...       1
# 1    KER ID=2 NAME="Stevenson">\nMr President, I se...       1
# 2    KER ID=3 LANGUAGE="NL" NAME="Peijs">\nMr Presi...       1
# 3    KER ID=4 LANGUAGE="DE" NAME="Swoboda">\nMr Pre...       1
# 4    KER ID=5 NAME="President">\nMr Swoboda, I can ...       1
# ..                                                 ...     ...
# 254  KER ID=255 LANGUAGE="FR" NAME="Berthu">\nMr Pr...      17
# 255  KER ID=256 LANGUAGE="DA" NAME="Krarup">\nI sho...      17
# 256  KER ID=257 LANGUAGE="DE" NAME="Karas">\nMr Pre...      17
# 257  KER ID=258 LANGUAGE="DE" NAME="Schreyer">\nMr ...      17
# 258  KER ID=259 NAME="President">\nThank you very m...      17
#
#                                          chapter_title     contribution_id  \
# 0      Adoption of the Minutes of the previous sitting    year-month-day-1
# 1      Adoption of the Minutes of the previous sitting    year-month-day-2
# 2      Adoption of the Minutes of the previous sitting    year-month-day-3
# 3      Adoption of the Minutes of the previous sitting    year-month-day-4
# 4      Adoption of the Minutes of the previous sitting    year-month-day-5
# ..                                                 ...                 ...
# 254  Increasing penal sanctions against counterfeit...  year-month-day-255
# 255  Increasing penal sanctions against counterfeit...  year-month-day-256
# 256  Increasing penal sanctions against counterfeit...  year-month-day-257
# 257  Increasing penal sanctions against counterfeit...  year-month-day-258
# 258  Increasing penal sanctions against counterfeit...  year-month-day-259
#
#     speaker_name language
# 0      President
# 1      Stevenson
# 2          Peijs       NL
# 3        Swoboda       DE
# 4      President
# ..           ...      ...
# 254       Berthu       FR
# 255       Krarup       DA
# 256        Karas       DE
# 257     Schreyer       DE
# 258    President
#
# [259 rows x 6 columns]
